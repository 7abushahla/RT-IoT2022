# %% [markdown]
# # GPU-IFIED CODE
# ### Can run with or without CUDA

# %%
import os
import json
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, cross_validate
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder, label_binarize
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_curve,
    auc,
    balanced_accuracy_score,
    f1_score,
    roc_auc_score,
    accuracy_score,
    precision_score,
    recall_score
)
from lightgbm import LGBMClassifier
import lightgbm as lgb

# %%
import gc
import random
from IPython.display import clear_output

# %%
import json

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Set the seed for reproducibility
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

# %%
# Settings
N_FOLDS = 10 #10
N_REPEATS = 3 #3
# BATCHSIZE = 128  # Not used 
CLASSES = 13
NUM_BOOST_ROUNDS = 100 # 1_500
EARLY_STOPPING_ROUNDS = 50
SAVE_MODEL_EVERY = 50
VERBOSE_EVAL = 5

# INPUT_SIZE = 83  # Not used

FIG_SIZE = (12, 12)
num_iters = "_100"
model_type = "_lgbm"
CHECKPOINT_DIR = f"./checkpoints{model_type}{num_iters}"

# %%
# Hyperparameters for LightGBM (from Optuna)

BEST_LGBM_PARAMS = {
    "bagging_fraction": 1.0,
    "bagging_freq": 0,
    "boosting_type": "goss",                       # was "gbdt"
    "cat_l2": 5.269360499169147,                  # was 0.026592839167437304
    "cat_smooth": 1.59391235805633e-06,           # was 0.0000016020190174477881
    "colsample_bytree": 0.848467246007983,        # was 0.6749537326452014
    # "feature_fraction": 0.8837732391319297,
    "feature_fraction_bynode": 0.7115856757331464, # was 0.319478870787565
    "learning_rate": 0.037300195761720965,        # was 0.023269571043269426
    "max_bin": 185,                               # was 229
    "max_depth": 40,                              # was 97
    "min_child_samples": 183,                     # was 291
    "min_child_weight": 4.1000432489806595,       # was 3.532669502811908
    "min_split_gain": 2.79022897258712,           # was 0.4728979135614666
    "num_leaves": 42,                             # was 143
    "reg_alpha": 6.019362118279061e-08,           # was 0.000008619857698099343
    "reg_lambda": 3.702480076077455e-05,          # was 0.015262204225165513
    "subsample": 1.0,
    "objective": "multiclass",
    "metric": "None",
    "num_class": CLASSES,
    "verbosity": -1,
    "seed": SEED,
    "n_jobs": -1                                  # Utilize all available cores
}

# %%
if not os.path.exists(CHECKPOINT_DIR):
    os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# %%
# Create necessary folders
def create_folders():
    folders = [
        f"outputs{model_type}{num_iters}/overall",
        f"outputs{model_type}{num_iters}/validation_model",
        f"outputs{model_type}{num_iters}/evaluation_model_full_training_set",
    ]
    
    for folder in folders:
        os.makedirs(folder, exist_ok=True)

# %%
create_folders()

# %%
save_path = f"outputs{model_type}{num_iters}/overall/"

# %%
# Custom Macro F1 score metric for LightGBM
def macro_f1_score(preds, train_data):
    y_true = train_data.get_label()
    num_class = len(np.unique(y_true))  # Assuming CLASSES is defined globally
    
    # Validate the length of preds
    if len(preds) == len(y_true):  # If preds are class indices
        # LightGBM
        # print("len(preds) == len(y_true)")
        y_pred = preds
    elif len(preds) == len(y_true) * num_class:  # If preds are probabilities
        # print("len(preds) == len(y_true) * num_class")
        y_pred = np.argmax(preds.reshape(len(y_true), num_class), axis=1)
    else:
        raise ValueError("Unexpected prediction shape")
    # Reshape preds to (num_instances, num_class)
    y_pred = np.argmax(preds.reshape(-1, num_class), axis=1)

    # # Reshape preds to (num_instances, num_class)
    # y_pred = np.argmax(preds.reshape(-1, num_class), axis=1)
    
    # Calculate Macro F1 Score
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    
    return 'macro_f1', macro_f1, True  # The third parameter 'True' indicates higher is better

# %%
# Cell 2: Load and Preprocess Data

def load_and_preprocess_data(filepath):
    """
    Loads data from a CSV file, replaces placeholders, and separates features from target.
    
    Args:
        filepath (str): Path to the CSV file.
        
    Returns:
        data (pd.DataFrame): Feature dataframe.
        target (pd.Series): Target labels.
        feature_names (list): List of feature names.
    """
    data = pd.read_csv(filepath)
    
    # Replace '-' with 'None' in categorical columns
    data['service'] = data['service'].replace('-', 'None')
    data['proto'] = data['proto'].replace('-', 'None')
    
    # Separate features and target
    feature_names = data.drop(columns=['Attack_type']).columns.tolist()
    target = data['Attack_type']
    data = data.drop(columns=['Attack_type'])
    
    return data, target, feature_names

# %%
# Load the dataset
data, target, feature_names = load_and_preprocess_data('./RT_IOT2022_new.csv')

# %%
def encode_targets(target):
    """
    Encodes categorical target labels into numerical codes.
    
    Args:
        target (pd.Series): Categorical target labels.
        
    Returns:
        target_encoded (np.ndarray): Encoded target labels.
        class_labels (list): List of class names.
        target_encoder (LabelEncoder): Fitted LabelEncoder instance.
    """
    target_encoder = LabelEncoder()
    target_encoded = target_encoder.fit_transform(target)
    class_labels = target_encoder.classes_
    return target_encoded, class_labels, target_encoder

# %%
# Encode target labels
Y_encoded, class_labels, target_encoder = encode_targets(target)

# %%
print(f"Number of unique classes: {len(class_labels)}")
print(f"Class labels: {class_labels}")
# Out:
# Number of unique classes: 13
# Class labels: ['ARP_poisioning' 'Alexa' 'DDOS_Slowloris' 'DOS_SYN_Hping' 'MQTT_Publish'
#  'Metasploit_Brute_Force_SSH' 'NMAP_FIN_SCAN' 'NMAP_OS_DETECTION'
#  'NMAP_TCP_scan' 'NMAP_UDP_SCAN' 'NMAP_XMAS_TREE_SCAN' 'Thing_Speak'
#  'Wipro_bulb']

# %%
# Split the data into train and test sets
X_train, X_test, Y_train, Y_test = train_test_split(
    data, Y_encoded, test_size=0.2, random_state=SEED, stratify=Y_encoded
)

print(f"Training set size: {X_train.shape}")
print(f"Test set size: {X_test.shape}")

# Clean up to save memory
del data
del target
# Out:
# Training set size: (167967, 83)
# Test set size: (41992, 83)

# %%
# Cell 5: Define Preprocessing and Model Pipeline

# Identify numerical and categorical columns
numerical_cols = X_train.select_dtypes(include=["int64", "float64", "float32"]).columns.tolist()
categorical_cols = ["proto", "service"]  # Adjust based on your data

# Update preprocessing for numerical and categorical columns
numerical_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])


# Define the preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ]
)

# Define LightGBM Classifier
lgbm_classifier = LGBMClassifier(**BEST_LGBM_PARAMS)

# Create the pipeline
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', lgbm_classifier)
])

# %%
from sklearn.metrics import make_scorer

# %% [markdown]
# ### NEW K-Fold (Correct)
# the best here is saved (best_lgbm_model.lgb), every fold is saved in

# %% [markdown]
# ------

# %%
import os
import json
import gc
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import (
    f1_score,
    balanced_accuracy_score,
    roc_auc_score,
    accuracy_score,
    precision_score,
    recall_score
)
from sklearn.preprocessing import label_binarize
import lightgbm as lgb

# Variables to track the best model (saved as a tuple: (preprocessor, booster))
best_macro_f1 = -float('inf')
best_model_path = os.path.join(CHECKPOINT_DIR, f"best_lgbm_model{num_iters}.txt")
best_model_with_prep_path = os.path.join(CHECKPOINT_DIR, f"best_lgbm_model_with_preproc_{num_iters}.joblib")

# Initialize cross-validation
rskf = RepeatedStratifiedKFold(n_splits=N_FOLDS, n_repeats=N_REPEATS, random_state=SEED)

for fold, (train_idx, val_idx) in enumerate(rskf.split(X_train, Y_train), 1): # enumerate starts from 1
    print(f"\nFold {fold}/{N_FOLDS * N_REPEATS}")
    
    # Split the data
    X_train_fold = X_train.iloc[train_idx].copy()
    Y_train_fold = Y_train[train_idx].copy()
    X_valid_fold = X_train.iloc[val_idx].copy()
    Y_valid_fold = Y_train[val_idx].copy()
    
    print(f"Before preprocessing: X_train_fold shape: {X_train_fold.shape}, "
          f"X_valid_fold shape: {X_valid_fold.shape}")
    
    # --- Preprocessing ---
    # Fit the preprocessor on the training fold and transform both sets
    preprocessor.fit(X_train_fold)
    X_train_transformed = preprocessor.transform(X_train_fold)
    X_valid_transformed = preprocessor.transform(X_valid_fold)
    
    print(f"After preprocessing: X_train_fold shape: {X_train_transformed.shape}, "
          f"X_valid_fold shape: {X_valid_transformed.shape}")
    
    # --- Create LightGBM Datasets ---
    dtrain = lgb.Dataset(X_train_transformed, label=Y_train_fold)
    dvalid = lgb.Dataset(X_valid_transformed, label=Y_valid_fold, reference=dtrain)
    
    # Initialize model for incremental training
    init_model = None
    checkpoint_path = os.path.join(CHECKPOINT_DIR, f"lgb_fold_{fold}{num_iters}.txt")
    if os.path.exists(checkpoint_path):
        print(f"Resuming training for fold {fold} from {checkpoint_path}")
        init_model = lgb.Booster(model_file=checkpoint_path)
    
    # --- Train LightGBM ---
    booster = lgb.train(
        params=BEST_LGBM_PARAMS,
        train_set=dtrain,
        valid_sets=[dtrain, dvalid],
        valid_names=['train', 'validation'],
        feval=macro_f1_score,
        num_boost_round=NUM_BOOST_ROUNDS,
        init_model=init_model,
        callbacks=[
            lgb.log_evaluation(VERBOSE_EVAL),
            lgb.early_stopping(EARLY_STOPPING_ROUNDS)
        ]
    )
    
    # # Optional: Save the booster checkpoint (if you wish to use LGBM's native save_model)
    # checkpoint_path = os.path.join(CHECKPOINT_DIR, f"lgb_fold_{fold}.lgbm")
    # booster.save_model(checkpoint_path)
    # print(f"Fold {fold} booster checkpoint saved to {checkpoint_path}")
    
    # --- Predictions ---
    # For predictions, the booster outputs probabilities.
    Y_train_pred_proba = booster.predict(X_train_transformed)
    Y_train_pred = np.argmax(Y_train_pred_proba.reshape(len(Y_train_fold), -1), axis=1)
    
    Y_valid_pred_proba = booster.predict(X_valid_transformed)
    Y_valid_pred = np.argmax(Y_valid_pred_proba.reshape(len(Y_valid_fold), -1), axis=1)
    
    # --- Compute Metrics ---
    # Training metrics
    train_bal_acc = balanced_accuracy_score(Y_train_fold, Y_train_pred)
    train_accuracy = accuracy_score(Y_train_fold, Y_train_pred)
    train_macro_f1 = f1_score(Y_train_fold, Y_train_pred, average='macro')
    train_precision = precision_score(Y_train_fold, Y_train_pred, average='macro', zero_division=0)
    train_recall = recall_score(Y_train_fold, Y_train_pred, average='macro', zero_division=0)
    train_auc = roc_auc_score(
        label_binarize(Y_train_fold, classes=np.arange(CLASSES)),
        Y_train_pred_proba,
        average='macro',
        multi_class='ovo'
    )
    
    # Validation metrics
    val_bal_acc = balanced_accuracy_score(Y_valid_fold, Y_valid_pred)
    val_accuracy = accuracy_score(Y_valid_fold, Y_valid_pred)
    val_macro_f1 = f1_score(Y_valid_fold, Y_valid_pred, average='macro')
    val_precision = precision_score(Y_valid_fold, Y_valid_pred, average='macro', zero_division=0)
    val_recall = recall_score(Y_valid_fold, Y_valid_pred, average='macro', zero_division=0)
    val_auc = roc_auc_score(
        label_binarize(Y_valid_fold, classes=np.arange(CLASSES)),
        Y_valid_pred_proba,
        average='macro',
        multi_class='ovo'
    )
    
    # Print Metrics
    print(f"Training Balanced Accuracy: {train_bal_acc:.4f}")
    print(f"Validation Balanced Accuracy: {val_bal_acc:.4f}")
    print(f"Training Accuracy: {train_accuracy:.4f}")
    print(f"Validation Accuracy: {val_accuracy:.4f}")
    print(f"Training Macro F1 Score: {train_macro_f1:.4f}")
    print(f"Validation Macro F1 Score: {val_macro_f1:.4f}")
    print(f"Training Precision (Macro): {train_precision:.4f}")
    print(f"Validation Precision (Macro): {val_precision:.4f}")
    print(f"Training Recall (Macro): {train_recall:.4f}")
    print(f"Validation Recall (Macro): {val_recall:.4f}")
    print(f"Training ROC AUC Score: {train_auc:.4f}")
    print(f"Validation ROC AUC Score: {val_auc:.4f}")
    
    # Save metrics for this fold, including predictions
    metrics = {
        "train_balanced_accuracy": train_bal_acc,
        "train_accuracy": train_accuracy,
        "train_macro_f1": train_macro_f1,
        "train_precision_macro": train_precision,
        "train_recall_macro": train_recall,
        "train_auc": train_auc,
        "validation_balanced_accuracy": val_bal_acc,
        "validation_accuracy": val_accuracy,
        "validation_macro_f1": val_macro_f1,
        "validation_precision_macro": val_precision,
        "validation_recall_macro": val_recall,
        "validation_auc": val_auc,
        "val_y_true": Y_valid_fold.tolist(),
        "val_y_pred": Y_valid_pred.tolist(),
        "val_y_score": Y_valid_pred_proba.tolist()
    }
    metrics_file = os.path.join(CHECKPOINT_DIR, f"metrics_fold{fold}{num_iters}.json")
    with open(metrics_file, 'w') as f:
        json.dump(metrics, f, indent=4)
    print(f"Metrics saved to {metrics_file}")
    
    # --- Save Best Model ---
    # If the current fold yields a higher Macro F1 on validation, update the best model.
    if val_macro_f1 > best_macro_f1:
        best_macro_f1 = val_macro_f1
        # Wrap the fold's preprocessor and booster into a tuple and save with joblib
        best_model = (preprocessor, booster.model_to_string())
        # best_model_with_prep_path = os.path.join(CHECKPOINT_DIR, f"best_lgbm_model_with_preproc_{num_iters}.joblib")
        joblib.dump(best_model, best_model_with_prep_path)


        booster.save_model(best_model_path)                 # native LightGBM format
        print(f"Best model updated and saved to {best_model_path} with Macro F1: {best_macro_f1:.4f}")
    
    # Optional: Save the model for each fold (as a tuple: (preprocessor, booster)) with joblib
    fold_model_path = os.path.join(CHECKPOINT_DIR, f"model_fold_with_preproc{fold}{num_iters}.txt")
    fold_model = (preprocessor, booster.model_to_string())
    joblib.dump(fold_model, fold_model_path)
    print(f"Model for fold {fold} saved to {fold_model_path}")
    
    # Clean up
    del X_train_fold, Y_train_fold, X_valid_fold, Y_valid_fold 
    gc.collect()

print("Cross-validation completed successfully.")
# Out:
# Fold 1/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.389148	validation's macro_f1: 0.387597
# [10]	train's macro_f1: 0.740982	validation's macro_f1: 0.737713
# [15]	train's macro_f1: 0.788274	validation's macro_f1: 0.771771
# [20]	train's macro_f1: 0.80573	validation's macro_f1: 0.79686
# [25]	train's macro_f1: 0.822756	validation's macro_f1: 0.816632
# [30]	train's macro_f1: 0.82601	validation's macro_f1: 0.827992
# [35]	train's macro_f1: 0.827532	validation's macro_f1: 0.830966
# [40]	train's macro_f1: 0.828572	validation's macro_f1: 0.831121
# [45]	train's macro_f1: 0.83215	validation's macro_f1: 0.83357
# [50]	train's macro_f1: 0.834105	validation's macro_f1: 0.835698
# [55]	train's macro_f1: 0.835867	validation's macro_f1: 0.835696
# [60]	train's macro_f1: 0.94902	validation's macro_f1: 0.974356
# [65]	train's macro_f1: 0.965484	validation's macro_f1: 0.9743
# [70]	train's macro_f1: 0.970393	validation's macro_f1: 0.974247
# [75]	train's macro_f1: 0.971121	validation's macro_f1: 0.974313
# [80]	train's macro_f1: 0.971186	validation's macro_f1: 0.974313
# [85]	train's macro_f1: 0.971321	validation's macro_f1: 0.974434
# [90]	train's macro_f1: 0.97133	validation's macro_f1: 0.974434
# [95]	train's macro_f1: 0.971399	validation's macro_f1: 0.974434
# [100]	train's macro_f1: 0.971476	validation's macro_f1: 0.974434
# Did not meet early stopping. Best iteration is:
# [85]	train's macro_f1: 0.971321	validation's macro_f1: 0.974434
# Training Balanced Accuracy: 0.9518
# Validation Balanced Accuracy: 0.9573
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9986
# Training Macro F1 Score: 0.9713
# Validation Macro F1 Score: 0.9744
# Training Precision (Macro): 0.9971
# Validation Precision (Macro): 0.9974
# Training Recall (Macro): 0.9518
# Validation Recall (Macro): 0.9573
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9997
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold1_100.json
# Best model updated and saved to ./checkpoints_lgbm_100\best_lgbm_model_100.txt with Macro F1: 0.9744
# Model for fold 1 saved to ./checkpoints_lgbm_100\model_fold_with_preproc1_100.txt
#
# Fold 2/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.434972	validation's macro_f1: 0.437197
# [10]	train's macro_f1: 0.741437	validation's macro_f1: 0.743197
# [15]	train's macro_f1: 0.760238	validation's macro_f1: 0.756682
# [20]	train's macro_f1: 0.795795	validation's macro_f1: 0.801853
# [25]	train's macro_f1: 0.820739	validation's macro_f1: 0.82736
# [30]	train's macro_f1: 0.824333	validation's macro_f1: 0.830568
# [35]	train's macro_f1: 0.828547	validation's macro_f1: 0.835228
# [40]	train's macro_f1: 0.831753	validation's macro_f1: 0.835168
# [45]	train's macro_f1: 0.833574	validation's macro_f1: 0.835695
# [50]	train's macro_f1: 0.834029	validation's macro_f1: 0.835825
# [55]	train's macro_f1: 0.840433	validation's macro_f1: 0.836189
# [60]	train's macro_f1: 0.934755	validation's macro_f1: 0.976977
# [65]	train's macro_f1: 0.960294	validation's macro_f1: 0.99242
# [70]	train's macro_f1: 0.960133	validation's macro_f1: 0.992186
# [75]	train's macro_f1: 0.967353	validation's macro_f1: 0.992186
# [80]	train's macro_f1: 0.967368	validation's macro_f1: 0.992252
# [85]	train's macro_f1: 0.967873	validation's macro_f1: 0.992252
# [90]	train's macro_f1: 0.968742	validation's macro_f1: 0.992306
# [95]	train's macro_f1: 0.968792	validation's macro_f1: 0.992936
# [100]	train's macro_f1: 0.968643	validation's macro_f1: 0.993
# Did not meet early stopping. Best iteration is:
# [98]	train's macro_f1: 0.968636	validation's macro_f1: 0.993067
# Training Balanced Accuracy: 0.9480
# Validation Balanced Accuracy: 0.9887
# Training Accuracy: 0.9985
# Validation Accuracy: 0.9987
# Training Macro F1 Score: 0.9686
# Validation Macro F1 Score: 0.9931
# Training Precision (Macro): 0.9969
# Validation Precision (Macro): 0.9979
# Training Recall (Macro): 0.9480
# Validation Recall (Macro): 0.9887
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 1.0000
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold2_100.json
# Best model updated and saved to ./checkpoints_lgbm_100\best_lgbm_model_100.txt with Macro F1: 0.9931
# Model for fold 2 saved to ./checkpoints_lgbm_100\model_fold_with_preproc2_100.txt
#
# Fold 3/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.435665	validation's macro_f1: 0.437253
# [10]	train's macro_f1: 0.74083	validation's macro_f1: 0.74468
# [15]	train's macro_f1: 0.75017	validation's macro_f1: 0.752192
# [20]	train's macro_f1: 0.803639	validation's macro_f1: 0.800523
# [25]	train's macro_f1: 0.819466	validation's macro_f1: 0.819652
# [30]	train's macro_f1: 0.826991	validation's macro_f1: 0.823038
# [35]	train's macro_f1: 0.8295	validation's macro_f1: 0.82858
# [40]	train's macro_f1: 0.830329	validation's macro_f1: 0.828854
# [45]	train's macro_f1: 0.831015	validation's macro_f1: 0.828857
# [50]	train's macro_f1: 0.83375	validation's macro_f1: 0.829409
# [55]	train's macro_f1: 0.834605	validation's macro_f1: 0.831845
# [60]	train's macro_f1: 0.930426	validation's macro_f1: 0.911163
# [65]	train's macro_f1: 0.945897	validation's macro_f1: 0.954026
# [70]	train's macro_f1: 0.960329	validation's macro_f1: 0.954158
# [75]	train's macro_f1: 0.968516	validation's macro_f1: 0.954158
# [80]	train's macro_f1: 0.968991	validation's macro_f1: 0.954288
# [85]	train's macro_f1: 0.97132	validation's macro_f1: 0.954288
# [90]	train's macro_f1: 0.97148	validation's macro_f1: 0.954354
# [95]	train's macro_f1: 0.971879	validation's macro_f1: 0.954488
# [100]	train's macro_f1: 0.971907	validation's macro_f1: 0.954556
# Did not meet early stopping. Best iteration is:
# [100]	train's macro_f1: 0.971907	validation's macro_f1: 0.954556
# Training Balanced Accuracy: 0.9534
# Validation Balanced Accuracy: 0.9381
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9984
# Training Macro F1 Score: 0.9719
# Validation Macro F1 Score: 0.9546
# Training Precision (Macro): 0.9966
# Validation Precision (Macro): 0.9969
# Training Recall (Macro): 0.9534
# Validation Recall (Macro): 0.9381
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9999
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold3_100.json
# Model for fold 3 saved to ./checkpoints_lgbm_100\model_fold_with_preproc3_100.txt
#
# Fold 4/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 93), X_valid_fold shape: (16797, 93)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.432951	validation's macro_f1: 0.431731
# [10]	train's macro_f1: 0.739818	validation's macro_f1: 0.741029
# [15]	train's macro_f1: 0.774803	validation's macro_f1: 0.773044
# [20]	train's macro_f1: 0.801545	validation's macro_f1: 0.797577
# [25]	train's macro_f1: 0.817944	validation's macro_f1: 0.812755
# [30]	train's macro_f1: 0.826338	validation's macro_f1: 0.818795
# [35]	train's macro_f1: 0.83037	validation's macro_f1: 0.819489
# [40]	train's macro_f1: 0.831255	validation's macro_f1: 0.819839
# [45]	train's macro_f1: 0.831684	validation's macro_f1: 0.820029
# [50]	train's macro_f1: 0.833089	validation's macro_f1: 0.822937
# [55]	train's macro_f1: 0.840103	validation's macro_f1: 0.825494
# [60]	train's macro_f1: 0.951404	validation's macro_f1: 0.884053
# [65]	train's macro_f1: 0.974076	validation's macro_f1: 0.922523
# [70]	train's macro_f1: 0.97462	validation's macro_f1: 0.922591
# [75]	train's macro_f1: 0.974704	validation's macro_f1: 0.922591
# [80]	train's macro_f1: 0.975171	validation's macro_f1: 0.924721
# [85]	train's macro_f1: 0.975185	validation's macro_f1: 0.924798
# [90]	train's macro_f1: 0.974978	validation's macro_f1: 0.920883
# [95]	train's macro_f1: 0.975019	validation's macro_f1: 0.920883
# [100]	train's macro_f1: 0.975277	validation's macro_f1: 0.920883
# Did not meet early stopping. Best iteration is:
# [86]	train's macro_f1: 0.975184	validation's macro_f1: 0.925979
# Training Balanced Accuracy: 0.9579
# Validation Balanced Accuracy: 0.8944
# Training Accuracy: 0.9985
# Validation Accuracy: 0.9980
# Training Macro F1 Score: 0.9752
# Validation Macro F1 Score: 0.9260
# Training Precision (Macro): 0.9970
# Validation Precision (Macro): 0.9966
# Training Recall (Macro): 0.9579
# Validation Recall (Macro): 0.8944
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9989
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold4_100.json
# Model for fold 4 saved to ./checkpoints_lgbm_100\model_fold_with_preproc4_100.txt
#
# Fold 5/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.410758	validation's macro_f1: 0.411943
# [10]	train's macro_f1: 0.739556	validation's macro_f1: 0.73908
# [15]	train's macro_f1: 0.783231	validation's macro_f1: 0.795208
# [20]	train's macro_f1: 0.804438	validation's macro_f1: 0.81011
# [25]	train's macro_f1: 0.812203	validation's macro_f1: 0.816886
# [30]	train's macro_f1: 0.82511	validation's macro_f1: 0.83011
# [35]	train's macro_f1: 0.827871	validation's macro_f1: 0.832655
# [40]	train's macro_f1: 0.828455	validation's macro_f1: 0.833236
# [45]	train's macro_f1: 0.83094	validation's macro_f1: 0.833373
# [50]	train's macro_f1: 0.83482	validation's macro_f1: 0.835342
# [55]	train's macro_f1: 0.836192	validation's macro_f1: 0.83549
# [60]	train's macro_f1: 0.957733	validation's macro_f1: 0.950944
# [65]	train's macro_f1: 0.97196	validation's macro_f1: 0.95101
# [70]	train's macro_f1: 0.97194	validation's macro_f1: 0.951077
# [75]	train's macro_f1: 0.972298	validation's macro_f1: 0.951143
# [80]	train's macro_f1: 0.972486	validation's macro_f1: 0.951274
# [85]	train's macro_f1: 0.972884	validation's macro_f1: 0.951274
# [90]	train's macro_f1: 0.973029	validation's macro_f1: 0.950439
# [95]	train's macro_f1: 0.973076	validation's macro_f1: 0.950439
# [100]	train's macro_f1: 0.973586	validation's macro_f1: 0.950439
# Did not meet early stopping. Best iteration is:
# [79]	train's macro_f1: 0.972369	validation's macro_f1: 0.951274
# Training Balanced Accuracy: 0.9530
# Validation Balanced Accuracy: 0.9322
# Training Accuracy: 0.9984
# Validation Accuracy: 0.9979
# Training Macro F1 Score: 0.9724
# Validation Macro F1 Score: 0.9513
# Training Precision (Macro): 0.9970
# Validation Precision (Macro): 0.9965
# Training Recall (Macro): 0.9530
# Validation Recall (Macro): 0.9322
# Training ROC AUC Score: 0.9998
# Validation ROC AUC Score: 0.9991
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold5_100.json
# Model for fold 5 saved to ./checkpoints_lgbm_100\model_fold_with_preproc5_100.txt
#
# Fold 6/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.409893	validation's macro_f1: 0.404767
# [10]	train's macro_f1: 0.742388	validation's macro_f1: 0.742214
# [15]	train's macro_f1: 0.77339	validation's macro_f1: 0.749354
# [20]	train's macro_f1: 0.797864	validation's macro_f1: 0.775175
# [25]	train's macro_f1: 0.816944	validation's macro_f1: 0.799573
# [30]	train's macro_f1: 0.823193	validation's macro_f1: 0.811341
# [35]	train's macro_f1: 0.826723	validation's macro_f1: 0.818208
# [40]	train's macro_f1: 0.828646	validation's macro_f1: 0.819886
# [45]	train's macro_f1: 0.832472	validation's macro_f1: 0.823184
# [50]	train's macro_f1: 0.833117	validation's macro_f1: 0.823057
# [55]	train's macro_f1: 0.839812	validation's macro_f1: 0.824805
# [60]	train's macro_f1: 0.951486	validation's macro_f1: 0.888015
# [65]	train's macro_f1: 0.972415	validation's macro_f1: 0.926794
# [70]	train's macro_f1: 0.974576	validation's macro_f1: 0.931337
# [75]	train's macro_f1: 0.974951	validation's macro_f1: 0.931337
# [80]	train's macro_f1: 0.975291	validation's macro_f1: 0.929133
# [85]	train's macro_f1: 0.975562	validation's macro_f1: 0.929199
# [90]	train's macro_f1: 0.975702	validation's macro_f1: 0.929075
# [95]	train's macro_f1: 0.975648	validation's macro_f1: 0.929075
# [100]	train's macro_f1: 0.975649	validation's macro_f1: 0.92914
# Did not meet early stopping. Best iteration is:
# [69]	train's macro_f1: 0.974561	validation's macro_f1: 0.931337
# Training Balanced Accuracy: 0.9567
# Validation Balanced Accuracy: 0.9001
# Training Accuracy: 0.9984
# Validation Accuracy: 0.9979
# Training Macro F1 Score: 0.9746
# Validation Macro F1 Score: 0.9313
# Training Precision (Macro): 0.9970
# Validation Precision (Macro): 0.9962
# Training Recall (Macro): 0.9567
# Validation Recall (Macro): 0.9001
# Training ROC AUC Score: 0.9998
# Validation ROC AUC Score: 0.9976
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold6_100.json
# Model for fold 6 saved to ./checkpoints_lgbm_100\model_fold_with_preproc6_100.txt
#
# Fold 7/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.383739	validation's macro_f1: 0.388742
# [10]	train's macro_f1: 0.743611	validation's macro_f1: 0.740627
# [15]	train's macro_f1: 0.78744	validation's macro_f1: 0.768991
# [20]	train's macro_f1: 0.812819	validation's macro_f1: 0.810321
# [25]	train's macro_f1: 0.820165	validation's macro_f1: 0.817719
# [30]	train's macro_f1: 0.827895	validation's macro_f1: 0.821142
# [35]	train's macro_f1: 0.828627	validation's macro_f1: 0.821777
# [40]	train's macro_f1: 0.829607	validation's macro_f1: 0.824368
# [45]	train's macro_f1: 0.830025	validation's macro_f1: 0.824572
# [50]	train's macro_f1: 0.834058	validation's macro_f1: 0.829909
# [55]	train's macro_f1: 0.834581	validation's macro_f1: 0.830237
# [60]	train's macro_f1: 0.870735	validation's macro_f1: 0.869136
# [65]	train's macro_f1: 0.961952	validation's macro_f1: 0.973923
# [70]	train's macro_f1: 0.969605	validation's macro_f1: 0.973923
# [75]	train's macro_f1: 0.970275	validation's macro_f1: 0.976191
# [80]	train's macro_f1: 0.970244	validation's macro_f1: 0.976312
# [85]	train's macro_f1: 0.970904	validation's macro_f1: 0.976257
# [90]	train's macro_f1: 0.970957	validation's macro_f1: 0.976378
# [95]	train's macro_f1: 0.97102	validation's macro_f1: 0.976378
# [100]	train's macro_f1: 0.971123	validation's macro_f1: 0.976378
# Did not meet early stopping. Best iteration is:
# [81]	train's macro_f1: 0.970404	validation's macro_f1: 0.976378
# Training Balanced Accuracy: 0.9501
# Validation Balanced Accuracy: 0.9628
# Training Accuracy: 0.9985
# Validation Accuracy: 0.9982
# Training Macro F1 Score: 0.9704
# Validation Macro F1 Score: 0.9764
# Training Precision (Macro): 0.9972
# Validation Precision (Macro): 0.9953
# Training Recall (Macro): 0.9501
# Validation Recall (Macro): 0.9628
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9996
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold7_100.json
# Model for fold 7 saved to ./checkpoints_lgbm_100\model_fold_with_preproc7_100.txt
#
# Fold 8/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 94), X_valid_fold shape: (16796, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.400342	validation's macro_f1: 0.409734
# [10]	train's macro_f1: 0.740819	validation's macro_f1: 0.735542
# [15]	train's macro_f1: 0.781024	validation's macro_f1: 0.769605
# [20]	train's macro_f1: 0.803173	validation's macro_f1: 0.784747
# [25]	train's macro_f1: 0.822516	validation's macro_f1: 0.807181
# [30]	train's macro_f1: 0.826713	validation's macro_f1: 0.810675
# [35]	train's macro_f1: 0.828669	validation's macro_f1: 0.814988
# [40]	train's macro_f1: 0.83072	validation's macro_f1: 0.820483
# [45]	train's macro_f1: 0.831814	validation's macro_f1: 0.824582
# [50]	train's macro_f1: 0.834011	validation's macro_f1: 0.832554
# [55]	train's macro_f1: 0.839979	validation's macro_f1: 0.837321
# [60]	train's macro_f1: 0.938636	validation's macro_f1: 0.952684
# [65]	train's macro_f1: 0.950133	validation's macro_f1: 0.952818
# [70]	train's macro_f1: 0.961347	validation's macro_f1: 0.952754
# [75]	train's macro_f1: 0.963916	validation's macro_f1: 0.975891
# [80]	train's macro_f1: 0.966535	validation's macro_f1: 0.993418
# [85]	train's macro_f1: 0.968877	validation's macro_f1: 0.993418
# [90]	train's macro_f1: 0.969172	validation's macro_f1: 0.993418
# [95]	train's macro_f1: 0.969578	validation's macro_f1: 0.993418
# [100]	train's macro_f1: 0.969315	validation's macro_f1: 0.99355
# Did not meet early stopping. Best iteration is:
# [97]	train's macro_f1: 0.969089	validation's macro_f1: 0.99355
# Training Balanced Accuracy: 0.9486
# Validation Balanced Accuracy: 0.9907
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9980
# Training Macro F1 Score: 0.9691
# Validation Macro F1 Score: 0.9935
# Training Precision (Macro): 0.9972
# Validation Precision (Macro): 0.9965
# Training Recall (Macro): 0.9486
# Validation Recall (Macro): 0.9907
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 1.0000
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold8_100.json
# Best model updated and saved to ./checkpoints_lgbm_100\best_lgbm_model_100.txt with Macro F1: 0.9935
# Model for fold 8 saved to ./checkpoints_lgbm_100\model_fold_with_preproc8_100.txt
#
# Fold 9/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 94), X_valid_fold shape: (16796, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.429614	validation's macro_f1: 0.430624
# [10]	train's macro_f1: 0.740199	validation's macro_f1: 0.739397
# [15]	train's macro_f1: 0.758151	validation's macro_f1: 0.747439
# [20]	train's macro_f1: 0.801737	validation's macro_f1: 0.807538
# [25]	train's macro_f1: 0.821291	validation's macro_f1: 0.820942
# [30]	train's macro_f1: 0.827436	validation's macro_f1: 0.827483
# [35]	train's macro_f1: 0.829232	validation's macro_f1: 0.827874
# [40]	train's macro_f1: 0.832698	validation's macro_f1: 0.830525
# [45]	train's macro_f1: 0.83293	validation's macro_f1: 0.828168
# [50]	train's macro_f1: 0.835886	validation's macro_f1: 0.830668
# [55]	train's macro_f1: 0.864262	validation's macro_f1: 0.830624
# [60]	train's macro_f1: 0.955015	validation's macro_f1: 0.948764
# [65]	train's macro_f1: 0.963017	validation's macro_f1: 0.948657
# [70]	train's macro_f1: 0.969926	validation's macro_f1: 0.971979
# [75]	train's macro_f1: 0.971363	validation's macro_f1: 0.971979
# [80]	train's macro_f1: 0.971752	validation's macro_f1: 0.972352
# [85]	train's macro_f1: 0.971767	validation's macro_f1: 0.972297
# [90]	train's macro_f1: 0.97202	validation's macro_f1: 0.972297
# [95]	train's macro_f1: 0.972608	validation's macro_f1: 0.97235
# [100]	train's macro_f1: 0.972689	validation's macro_f1: 0.97235
# Did not meet early stopping. Best iteration is:
# [79]	train's macro_f1: 0.971751	validation's macro_f1: 0.972352
# Training Balanced Accuracy: 0.9527
# Validation Balanced Accuracy: 0.9545
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9977
# Training Macro F1 Score: 0.9718
# Validation Macro F1 Score: 0.9724
# Training Precision (Macro): 0.9970
# Validation Precision (Macro): 0.9963
# Training Recall (Macro): 0.9527
# Validation Recall (Macro): 0.9545
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9998
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold9_100.json
# Model for fold 9 saved to ./checkpoints_lgbm_100\model_fold_with_preproc9_100.txt
#
# Fold 10/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 94), X_valid_fold shape: (16796, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.407284	validation's macro_f1: 0.407222
# [10]	train's macro_f1: 0.739332	validation's macro_f1: 0.740088
# [15]	train's macro_f1: 0.75623	validation's macro_f1: 0.75549
# [20]	train's macro_f1: 0.787662	validation's macro_f1: 0.786297
# [25]	train's macro_f1: 0.820147	validation's macro_f1: 0.810325
# [30]	train's macro_f1: 0.823675	validation's macro_f1: 0.814369
# [35]	train's macro_f1: 0.829251	validation's macro_f1: 0.821771
# [40]	train's macro_f1: 0.831916	validation's macro_f1: 0.825843
# [45]	train's macro_f1: 0.833422	validation's macro_f1: 0.830775
# [50]	train's macro_f1: 0.834245	validation's macro_f1: 0.828475
# [55]	train's macro_f1: 0.840071	validation's macro_f1: 0.831108
# [60]	train's macro_f1: 0.947547	validation's macro_f1: 0.882543
# [65]	train's macro_f1: 0.962674	validation's macro_f1: 0.92108
# [70]	train's macro_f1: 0.965411	validation's macro_f1: 0.944228
# [75]	train's macro_f1: 0.970811	validation's macro_f1: 0.959683
# [80]	train's macro_f1: 0.970762	validation's macro_f1: 0.959502
# [85]	train's macro_f1: 0.971279	validation's macro_f1: 0.959449
# [90]	train's macro_f1: 0.971391	validation's macro_f1: 0.959328
# [95]	train's macro_f1: 0.971689	validation's macro_f1: 0.959328
# [100]	train's macro_f1: 0.972381	validation's macro_f1: 0.959328
# Did not meet early stopping. Best iteration is:
# [75]	train's macro_f1: 0.970811	validation's macro_f1: 0.959683
# Training Balanced Accuracy: 0.9513
# Validation Balanced Accuracy: 0.9392
# Training Accuracy: 0.9985
# Validation Accuracy: 0.9979
# Training Macro F1 Score: 0.9708
# Validation Macro F1 Score: 0.9597
# Training Precision (Macro): 0.9976
# Validation Precision (Macro): 0.9948
# Training Recall (Macro): 0.9513
# Validation Recall (Macro): 0.9392
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9989
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold10_100.json
# Model for fold 10 saved to ./checkpoints_lgbm_100\model_fold_with_preproc10_100.txt
#
# Fold 11/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.403085	validation's macro_f1: 0.403208
# [10]	train's macro_f1: 0.743453	validation's macro_f1: 0.745543
# [15]	train's macro_f1: 0.769748	validation's macro_f1: 0.784628
# [20]	train's macro_f1: 0.808198	validation's macro_f1: 0.813359
# [25]	train's macro_f1: 0.820258	validation's macro_f1: 0.824133
# [30]	train's macro_f1: 0.825987	validation's macro_f1: 0.830282
# [35]	train's macro_f1: 0.827171	validation's macro_f1: 0.830409
# [40]	train's macro_f1: 0.827589	validation's macro_f1: 0.833219
# [45]	train's macro_f1: 0.830442	validation's macro_f1: 0.833155
# [50]	train's macro_f1: 0.833289	validation's macro_f1: 0.833451
# [55]	train's macro_f1: 0.840595	validation's macro_f1: 0.833411
# [60]	train's macro_f1: 0.934633	validation's macro_f1: 0.972088
# [65]	train's macro_f1: 0.955084	validation's macro_f1: 0.991809
# [70]	train's macro_f1: 0.966042	validation's macro_f1: 0.991878
# [75]	train's macro_f1: 0.968247	validation's macro_f1: 0.991878
# [80]	train's macro_f1: 0.968409	validation's macro_f1: 0.991878
# [85]	train's macro_f1: 0.968543	validation's macro_f1: 0.991947
# [90]	train's macro_f1: 0.968917	validation's macro_f1: 0.99398
# [95]	train's macro_f1: 0.96885	validation's macro_f1: 0.99398
# [100]	train's macro_f1: 0.968738	validation's macro_f1: 0.99398
# Did not meet early stopping. Best iteration is:
# [86]	train's macro_f1: 0.968564	validation's macro_f1: 0.99398
# Training Balanced Accuracy: 0.9475
# Validation Balanced Accuracy: 0.9938
# Training Accuracy: 0.9985
# Validation Accuracy: 0.9982
# Training Macro F1 Score: 0.9686
# Validation Macro F1 Score: 0.9940
# Training Precision (Macro): 0.9973
# Validation Precision (Macro): 0.9942
# Training Recall (Macro): 0.9475
# Validation Recall (Macro): 0.9938
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 1.0000
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold11_100.json
# Best model updated and saved to ./checkpoints_lgbm_100\best_lgbm_model_100.txt with Macro F1: 0.9940
# Model for fold 11 saved to ./checkpoints_lgbm_100\model_fold_with_preproc11_100.txt
#
# Fold 12/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.386293	validation's macro_f1: 0.384208
# [10]	train's macro_f1: 0.742266	validation's macro_f1: 0.743762
# [15]	train's macro_f1: 0.784378	validation's macro_f1: 0.78224
# [20]	train's macro_f1: 0.803549	validation's macro_f1: 0.804397
# [25]	train's macro_f1: 0.821191	validation's macro_f1: 0.809302
# [30]	train's macro_f1: 0.82709	validation's macro_f1: 0.822526
# [35]	train's macro_f1: 0.828089	validation's macro_f1: 0.825291
# [40]	train's macro_f1: 0.829834	validation's macro_f1: 0.828479
# [45]	train's macro_f1: 0.832327	validation's macro_f1: 0.828427
# [50]	train's macro_f1: 0.834468	validation's macro_f1: 0.831128
# [55]	train's macro_f1: 0.834656	validation's macro_f1: 0.831398
# [60]	train's macro_f1: 0.934388	validation's macro_f1: 0.908453
# [65]	train's macro_f1: 0.950063	validation's macro_f1: 0.946773
# [70]	train's macro_f1: 0.964167	validation's macro_f1: 0.972226
# [75]	train's macro_f1: 0.969426	validation's macro_f1: 0.987549
# [80]	train's macro_f1: 0.969434	validation's macro_f1: 0.987616
# [85]	train's macro_f1: 0.96943	validation's macro_f1: 0.987616
# [90]	train's macro_f1: 0.969333	validation's macro_f1: 0.987442
# [95]	train's macro_f1: 0.969417	validation's macro_f1: 0.988005
# [100]	train's macro_f1: 0.969739	validation's macro_f1: 0.988069
# Did not meet early stopping. Best iteration is:
# [98]	train's macro_f1: 0.969465	validation's macro_f1: 0.988072
# Training Balanced Accuracy: 0.9497
# Validation Balanced Accuracy: 0.9812
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9972
# Training Macro F1 Score: 0.9695
# Validation Macro F1 Score: 0.9881
# Training Precision (Macro): 0.9968
# Validation Precision (Macro): 0.9959
# Training Recall (Macro): 0.9497
# Validation Recall (Macro): 0.9812
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9999
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold12_100.json
# Model for fold 12 saved to ./checkpoints_lgbm_100\model_fold_with_preproc12_100.txt
#
# Fold 13/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.406829	validation's macro_f1: 0.406186
# [10]	train's macro_f1: 0.737772	validation's macro_f1: 0.736429
# [15]	train's macro_f1: 0.759164	validation's macro_f1: 0.75025
# [20]	train's macro_f1: 0.796291	validation's macro_f1: 0.79145
# [25]	train's macro_f1: 0.817085	validation's macro_f1: 0.819466
# [30]	train's macro_f1: 0.821385	validation's macro_f1: 0.828138
# [35]	train's macro_f1: 0.827568	validation's macro_f1: 0.832917
# [40]	train's macro_f1: 0.829622	validation's macro_f1: 0.837605
# [45]	train's macro_f1: 0.83312	validation's macro_f1: 0.837671
# [50]	train's macro_f1: 0.833972	validation's macro_f1: 0.837861
# [55]	train's macro_f1: 0.910309	validation's macro_f1: 0.837875
# [60]	train's macro_f1: 0.935635	validation's macro_f1: 0.876461
# [65]	train's macro_f1: 0.962299	validation's macro_f1: 0.899731
# [70]	train's macro_f1: 0.964843	validation's macro_f1: 0.899721
# [75]	train's macro_f1: 0.970217	validation's macro_f1: 0.899853
# [80]	train's macro_f1: 0.972914	validation's macro_f1: 0.899853
# [85]	train's macro_f1: 0.973181	validation's macro_f1: 0.899433
# [90]	train's macro_f1: 0.973119	validation's macro_f1: 0.915011
# [95]	train's macro_f1: 0.973439	validation's macro_f1: 0.915011
# [100]	train's macro_f1: 0.973372	validation's macro_f1: 0.915077
# Did not meet early stopping. Best iteration is:
# [100]	train's macro_f1: 0.973372	validation's macro_f1: 0.915077
# Training Balanced Accuracy: 0.9567
# Validation Balanced Accuracy: 0.9105
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9983
# Training Macro F1 Score: 0.9734
# Validation Macro F1 Score: 0.9151
# Training Precision (Macro): 0.9969
# Validation Precision (Macro): 0.9200
# Training Recall (Macro): 0.9567
# Validation Recall (Macro): 0.9105
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9988
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold13_100.json
# Model for fold 13 saved to ./checkpoints_lgbm_100\model_fold_with_preproc13_100.txt
#
# Fold 14/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 93), X_valid_fold shape: (16797, 93)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.4051	validation's macro_f1: 0.404791
# [10]	train's macro_f1: 0.741999	validation's macro_f1: 0.742384
# [15]	train's macro_f1: 0.773978	validation's macro_f1: 0.771397
# [20]	train's macro_f1: 0.800553	validation's macro_f1: 0.800469
# [25]	train's macro_f1: 0.820607	validation's macro_f1: 0.820216
# [30]	train's macro_f1: 0.825972	validation's macro_f1: 0.826164
# [35]	train's macro_f1: 0.827967	validation's macro_f1: 0.826749
# [40]	train's macro_f1: 0.828975	validation's macro_f1: 0.826994
# [45]	train's macro_f1: 0.829494	validation's macro_f1: 0.827208
# [50]	train's macro_f1: 0.833563	validation's macro_f1: 0.82787
# [55]	train's macro_f1: 0.865884	validation's macro_f1: 0.827872
# [60]	train's macro_f1: 0.959866	validation's macro_f1: 0.907232
# [65]	train's macro_f1: 0.960381	validation's macro_f1: 0.948069
# [70]	train's macro_f1: 0.971442	validation's macro_f1: 0.950082
# [75]	train's macro_f1: 0.971831	validation's macro_f1: 0.954204
# [80]	train's macro_f1: 0.972647	validation's macro_f1: 0.954214
# [85]	train's macro_f1: 0.972722	validation's macro_f1: 0.954398
# [90]	train's macro_f1: 0.972757	validation's macro_f1: 0.954398
# [95]	train's macro_f1: 0.972898	validation's macro_f1: 0.954398
# [100]	train's macro_f1: 0.972905	validation's macro_f1: 0.954467
# Did not meet early stopping. Best iteration is:
# [98]	train's macro_f1: 0.972905	validation's macro_f1: 0.954467
# Training Balanced Accuracy: 0.9538
# Validation Balanced Accuracy: 0.9382
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9983
# Training Macro F1 Score: 0.9729
# Validation Macro F1 Score: 0.9545
# Training Precision (Macro): 0.9972
# Validation Precision (Macro): 0.9966
# Training Recall (Macro): 0.9538
# Validation Recall (Macro): 0.9382
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9990
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold14_100.json
# Model for fold 14 saved to ./checkpoints_lgbm_100\model_fold_with_preproc14_100.txt
#
# Fold 15/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.395242	validation's macro_f1: 0.393129
# [10]	train's macro_f1: 0.742251	validation's macro_f1: 0.735367
# [15]	train's macro_f1: 0.76382	validation's macro_f1: 0.745366
# [20]	train's macro_f1: 0.799801	validation's macro_f1: 0.781176
# [25]	train's macro_f1: 0.818633	validation's macro_f1: 0.799998
# [30]	train's macro_f1: 0.82363	validation's macro_f1: 0.807861
# [35]	train's macro_f1: 0.829776	validation's macro_f1: 0.82017
# [40]	train's macro_f1: 0.830396	validation's macro_f1: 0.820595
# [45]	train's macro_f1: 0.831378	validation's macro_f1: 0.820864
# [50]	train's macro_f1: 0.833834	validation's macro_f1: 0.820932
# [55]	train's macro_f1: 0.870163	validation's macro_f1: 0.826599
# [60]	train's macro_f1: 0.959302	validation's macro_f1: 0.908389
# [65]	train's macro_f1: 0.96302	validation's macro_f1: 0.946788
# [70]	train's macro_f1: 0.966302	validation's macro_f1: 0.946973
# [75]	train's macro_f1: 0.972656	validation's macro_f1: 0.946918
# [80]	train's macro_f1: 0.972748	validation's macro_f1: 0.946918
# [85]	train's macro_f1: 0.972782	validation's macro_f1: 0.946983
# [90]	train's macro_f1: 0.972848	validation's macro_f1: 0.947049
# [95]	train's macro_f1: 0.972709	validation's macro_f1: 0.947049
# [100]	train's macro_f1: 0.974703	validation's macro_f1: 0.947117
# Did not meet early stopping. Best iteration is:
# [99]	train's macro_f1: 0.974695	validation's macro_f1: 0.947117
# Training Balanced Accuracy: 0.9564
# Validation Balanced Accuracy: 0.9248
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9982
# Training Macro F1 Score: 0.9747
# Validation Macro F1 Score: 0.9471
# Training Precision (Macro): 0.9972
# Validation Precision (Macro): 0.9968
# Training Recall (Macro): 0.9564
# Validation Recall (Macro): 0.9248
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9996
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold15_100.json
# Model for fold 15 saved to ./checkpoints_lgbm_100\model_fold_with_preproc15_100.txt
#
# Fold 16/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.407115	validation's macro_f1: 0.406386
# [10]	train's macro_f1: 0.740636	validation's macro_f1: 0.741415
# [15]	train's macro_f1: 0.758954	validation's macro_f1: 0.75112
# [20]	train's macro_f1: 0.809458	validation's macro_f1: 0.783658
# [25]	train's macro_f1: 0.820509	validation's macro_f1: 0.813127
# [30]	train's macro_f1: 0.825878	validation's macro_f1: 0.819959
# [35]	train's macro_f1: 0.828324	validation's macro_f1: 0.822767
# [40]	train's macro_f1: 0.829587	validation's macro_f1: 0.823032
# [45]	train's macro_f1: 0.830032	validation's macro_f1: 0.823543
# [50]	train's macro_f1: 0.832781	validation's macro_f1: 0.826238
# [55]	train's macro_f1: 0.839644	validation's macro_f1: 0.826369
# [60]	train's macro_f1: 0.868886	validation's macro_f1: 0.891083
# [65]	train's macro_f1: 0.958084	validation's macro_f1: 0.968102
# [70]	train's macro_f1: 0.969984	validation's macro_f1: 0.968102
# [75]	train's macro_f1: 0.970159	validation's macro_f1: 0.968102
# [80]	train's macro_f1: 0.971088	validation's macro_f1: 0.968102
# [85]	train's macro_f1: 0.971171	validation's macro_f1: 0.96835
# [90]	train's macro_f1: 0.971488	validation's macro_f1: 0.968482
# [95]	train's macro_f1: 0.971288	validation's macro_f1: 0.968482
# [100]	train's macro_f1: 0.971552	validation's macro_f1: 0.968602
# Did not meet early stopping. Best iteration is:
# [99]	train's macro_f1: 0.971552	validation's macro_f1: 0.968602
# Training Balanced Accuracy: 0.9526
# Validation Balanced Accuracy: 0.9488
# Training Accuracy: 0.9987
# Validation Accuracy: 0.9978
# Training Macro F1 Score: 0.9716
# Validation Macro F1 Score: 0.9686
# Training Precision (Macro): 0.9968
# Validation Precision (Macro): 0.9963
# Training Recall (Macro): 0.9526
# Validation Recall (Macro): 0.9488
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9998
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold16_100.json
# Model for fold 16 saved to ./checkpoints_lgbm_100\model_fold_with_preproc16_100.txt
#
# Fold 17/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.408821	validation's macro_f1: 0.40734
# [10]	train's macro_f1: 0.738785	validation's macro_f1: 0.742418
# [15]	train's macro_f1: 0.767979	validation's macro_f1: 0.773172
# [20]	train's macro_f1: 0.799703	validation's macro_f1: 0.804261
# [25]	train's macro_f1: 0.814056	validation's macro_f1: 0.812511
# [30]	train's macro_f1: 0.819786	validation's macro_f1: 0.820377
# [35]	train's macro_f1: 0.827309	validation's macro_f1: 0.823325
# [40]	train's macro_f1: 0.82998	validation's macro_f1: 0.829001
# [45]	train's macro_f1: 0.833714	validation's macro_f1: 0.829014
# [50]	train's macro_f1: 0.834353	validation's macro_f1: 0.829135
# [55]	train's macro_f1: 0.840647	validation's macro_f1: 0.834249
# [60]	train's macro_f1: 0.88051	validation's macro_f1: 0.836377
# [65]	train's macro_f1: 0.963948	validation's macro_f1: 0.951839
# [70]	train's macro_f1: 0.969489	validation's macro_f1: 0.95392
# [75]	train's macro_f1: 0.971974	validation's macro_f1: 0.956019
# [80]	train's macro_f1: 0.972423	validation's macro_f1: 0.956085
# [85]	train's macro_f1: 0.973148	validation's macro_f1: 0.956021
# [90]	train's macro_f1: 0.973643	validation's macro_f1: 0.956089
# [95]	train's macro_f1: 0.973764	validation's macro_f1: 0.956034
# [100]	train's macro_f1: 0.974064	validation's macro_f1: 0.956034
# Did not meet early stopping. Best iteration is:
# [90]	train's macro_f1: 0.973643	validation's macro_f1: 0.956089
# Training Balanced Accuracy: 0.9553
# Validation Balanced Accuracy: 0.9410
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9985
# Training Macro F1 Score: 0.9736
# Validation Macro F1 Score: 0.9561
# Training Precision (Macro): 0.9972
# Validation Precision (Macro): 0.9970
# Training Recall (Macro): 0.9553
# Validation Recall (Macro): 0.9410
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9994
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold17_100.json
# Model for fold 17 saved to ./checkpoints_lgbm_100\model_fold_with_preproc17_100.txt
#
# Fold 18/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 94), X_valid_fold shape: (16796, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.398363	validation's macro_f1: 0.399433
# [10]	train's macro_f1: 0.743181	validation's macro_f1: 0.737933
# [15]	train's macro_f1: 0.787573	validation's macro_f1: 0.77371
# [20]	train's macro_f1: 0.803598	validation's macro_f1: 0.801752
# [25]	train's macro_f1: 0.823698	validation's macro_f1: 0.821321
# [30]	train's macro_f1: 0.82795	validation's macro_f1: 0.821933
# [35]	train's macro_f1: 0.828206	validation's macro_f1: 0.824814
# [40]	train's macro_f1: 0.828718	validation's macro_f1: 0.827602
# [45]	train's macro_f1: 0.829681	validation's macro_f1: 0.827808
# [50]	train's macro_f1: 0.832453	validation's macro_f1: 0.830666
# [55]	train's macro_f1: 0.833783	validation's macro_f1: 0.833114
# [60]	train's macro_f1: 0.935684	validation's macro_f1: 0.884349
# [65]	train's macro_f1: 0.956184	validation's macro_f1: 0.9487
# [70]	train's macro_f1: 0.971241	validation's macro_f1: 0.951068
# [75]	train's macro_f1: 0.972111	validation's macro_f1: 0.950834
# [80]	train's macro_f1: 0.972846	validation's macro_f1: 0.951095
# [85]	train's macro_f1: 0.97291	validation's macro_f1: 0.951095
# [90]	train's macro_f1: 0.973066	validation's macro_f1: 0.951095
# [95]	train's macro_f1: 0.973098	validation's macro_f1: 0.950919
# [100]	train's macro_f1: 0.973561	validation's macro_f1: 0.95104
# Did not meet early stopping. Best iteration is:
# [80]	train's macro_f1: 0.972846	validation's macro_f1: 0.951095
# Training Balanced Accuracy: 0.9546
# Validation Balanced Accuracy: 0.9234
# Training Accuracy: 0.9984
# Validation Accuracy: 0.9987
# Training Macro F1 Score: 0.9728
# Validation Macro F1 Score: 0.9511
# Training Precision (Macro): 0.9969
# Validation Precision (Macro): 0.9972
# Training Recall (Macro): 0.9546
# Validation Recall (Macro): 0.9234
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9997
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold18_100.json
# Model for fold 18 saved to ./checkpoints_lgbm_100\model_fold_with_preproc18_100.txt
#
# Fold 19/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 94), X_valid_fold shape: (16796, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.4068	validation's macro_f1: 0.410522
# [10]	train's macro_f1: 0.740511	validation's macro_f1: 0.741621
# [15]	train's macro_f1: 0.773661	validation's macro_f1: 0.771429
# [20]	train's macro_f1: 0.801979	validation's macro_f1: 0.794284
# [25]	train's macro_f1: 0.813887	validation's macro_f1: 0.800974
# [30]	train's macro_f1: 0.823261	validation's macro_f1: 0.819323
# [35]	train's macro_f1: 0.828467	validation's macro_f1: 0.822258
# [40]	train's macro_f1: 0.830825	validation's macro_f1: 0.827534
# [45]	train's macro_f1: 0.832172	validation's macro_f1: 0.828863
# [50]	train's macro_f1: 0.833018	validation's macro_f1: 0.831498
# [55]	train's macro_f1: 0.862839	validation's macro_f1: 0.872283
# [60]	train's macro_f1: 0.953965	validation's macro_f1: 0.97468
# [65]	train's macro_f1: 0.962931	validation's macro_f1: 0.97468
# [70]	train's macro_f1: 0.970363	validation's macro_f1: 0.974746
# [75]	train's macro_f1: 0.970152	validation's macro_f1: 0.974812
# [80]	train's macro_f1: 0.970281	validation's macro_f1: 0.974812
# [85]	train's macro_f1: 0.970311	validation's macro_f1: 0.974878
# [90]	train's macro_f1: 0.970935	validation's macro_f1: 0.974878
# [95]	train's macro_f1: 0.970955	validation's macro_f1: 0.974878
# [100]	train's macro_f1: 0.971877	validation's macro_f1: 0.977192
# Did not meet early stopping. Best iteration is:
# [99]	train's macro_f1: 0.971855	validation's macro_f1: 0.977192
# Training Balanced Accuracy: 0.9529
# Validation Balanced Accuracy: 0.9635
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9980
# Training Macro F1 Score: 0.9719
# Validation Macro F1 Score: 0.9772
# Training Precision (Macro): 0.9970
# Validation Precision (Macro): 0.9962
# Training Recall (Macro): 0.9529
# Validation Recall (Macro): 0.9635
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9999
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold19_100.json
# Model for fold 19 saved to ./checkpoints_lgbm_100\model_fold_with_preproc19_100.txt
#
# Fold 20/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 94), X_valid_fold shape: (16796, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.398144	validation's macro_f1: 0.395448
# [10]	train's macro_f1: 0.743437	validation's macro_f1: 0.738042
# [15]	train's macro_f1: 0.773505	validation's macro_f1: 0.767655
# [20]	train's macro_f1: 0.80443	validation's macro_f1: 0.797489
# [25]	train's macro_f1: 0.822595	validation's macro_f1: 0.82145
# [30]	train's macro_f1: 0.826453	validation's macro_f1: 0.824865
# [35]	train's macro_f1: 0.827271	validation's macro_f1: 0.825412
# [40]	train's macro_f1: 0.829477	validation's macro_f1: 0.828232
# [45]	train's macro_f1: 0.832565	validation's macro_f1: 0.830759
# [50]	train's macro_f1: 0.834453	validation's macro_f1: 0.83096
# [55]	train's macro_f1: 0.835395	validation's macro_f1: 0.831028
# [60]	train's macro_f1: 0.941417	validation's macro_f1: 0.907962
# [65]	train's macro_f1: 0.960998	validation's macro_f1: 0.908083
# [70]	train's macro_f1: 0.970324	validation's macro_f1: 0.969928
# [75]	train's macro_f1: 0.970429	validation's macro_f1: 0.96923
# [80]	train's macro_f1: 0.97067	validation's macro_f1: 0.969296
# [85]	train's macro_f1: 0.971153	validation's macro_f1: 0.969365
# [90]	train's macro_f1: 0.971543	validation's macro_f1: 0.969319
# [95]	train's macro_f1: 0.971597	validation's macro_f1: 0.969384
# [100]	train's macro_f1: 0.971313	validation's macro_f1: 0.969384
# Did not meet early stopping. Best iteration is:
# [70]	train's macro_f1: 0.970324	validation's macro_f1: 0.969928
# Training Balanced Accuracy: 0.9503
# Validation Balanced Accuracy: 0.9507
# Training Accuracy: 0.9984
# Validation Accuracy: 0.9979
# Training Macro F1 Score: 0.9703
# Validation Macro F1 Score: 0.9699
# Training Precision (Macro): 0.9967
# Validation Precision (Macro): 0.9971
# Training Recall (Macro): 0.9503
# Validation Recall (Macro): 0.9507
# Training ROC AUC Score: 0.9998
# Validation ROC AUC Score: 0.9998
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold20_100.json
# Model for fold 20 saved to ./checkpoints_lgbm_100\model_fold_with_preproc20_100.txt
#
# Fold 21/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.429526	validation's macro_f1: 0.433313
# [10]	train's macro_f1: 0.739174	validation's macro_f1: 0.733454
# [15]	train's macro_f1: 0.761423	validation's macro_f1: 0.747659
# [20]	train's macro_f1: 0.794936	validation's macro_f1: 0.790378
# [25]	train's macro_f1: 0.81804	validation's macro_f1: 0.821313
# [30]	train's macro_f1: 0.825278	validation's macro_f1: 0.824393
# [35]	train's macro_f1: 0.82874	validation's macro_f1: 0.824858
# [40]	train's macro_f1: 0.829695	validation's macro_f1: 0.824995
# [45]	train's macro_f1: 0.833545	validation's macro_f1: 0.827752
# [50]	train's macro_f1: 0.834496	validation's macro_f1: 0.829357
# [55]	train's macro_f1: 0.834697	validation's macro_f1: 0.829424
# [60]	train's macro_f1: 0.90611	validation's macro_f1: 0.906415
# [65]	train's macro_f1: 0.952709	validation's macro_f1: 0.983587
# [70]	train's macro_f1: 0.95891	validation's macro_f1: 0.983788
# [75]	train's macro_f1: 0.969125	validation's macro_f1: 0.983854
# [80]	train's macro_f1: 0.969553	validation's macro_f1: 0.98392
# [85]	train's macro_f1: 0.96967	validation's macro_f1: 0.983854
# [90]	train's macro_f1: 0.969837	validation's macro_f1: 0.983865
# [95]	train's macro_f1: 0.969758	validation's macro_f1: 0.983865
# [100]	train's macro_f1: 0.969741	validation's macro_f1: 0.983865
# Did not meet early stopping. Best iteration is:
# [87]	train's macro_f1: 0.9697	validation's macro_f1: 0.983986
# Training Balanced Accuracy: 0.9498
# Validation Balanced Accuracy: 0.9737
# Training Accuracy: 0.9985
# Validation Accuracy: 0.9979
# Training Macro F1 Score: 0.9697
# Validation Macro F1 Score: 0.9840
# Training Precision (Macro): 0.9972
# Validation Precision (Macro): 0.9964
# Training Recall (Macro): 0.9498
# Validation Recall (Macro): 0.9737
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9999
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold21_100.json
# Model for fold 21 saved to ./checkpoints_lgbm_100\model_fold_with_preproc21_100.txt
#
# Fold 22/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.399987	validation's macro_f1: 0.404337
# [10]	train's macro_f1: 0.740576	validation's macro_f1: 0.744347
# [15]	train's macro_f1: 0.767747	validation's macro_f1: 0.764897
# [20]	train's macro_f1: 0.798311	validation's macro_f1: 0.786763
# [25]	train's macro_f1: 0.816215	validation's macro_f1: 0.809867
# [30]	train's macro_f1: 0.824609	validation's macro_f1: 0.822271
# [35]	train's macro_f1: 0.827306	validation's macro_f1: 0.825114
# [40]	train's macro_f1: 0.8307	validation's macro_f1: 0.825199
# [45]	train's macro_f1: 0.83376	validation's macro_f1: 0.830304
# [50]	train's macro_f1: 0.834594	validation's macro_f1: 0.832696
# [55]	train's macro_f1: 0.834981	validation's macro_f1: 0.832896
# [60]	train's macro_f1: 0.940645	validation's macro_f1: 0.886394
# [65]	train's macro_f1: 0.964556	validation's macro_f1: 0.94997
# [70]	train's macro_f1: 0.970259	validation's macro_f1: 0.967327
# [75]	train's macro_f1: 0.970734	validation's macro_f1: 0.967327
# [80]	train's macro_f1: 0.97339	validation's macro_f1: 0.966487
# [85]	train's macro_f1: 0.973488	validation's macro_f1: 0.967576
# [90]	train's macro_f1: 0.973779	validation's macro_f1: 0.96751
# [95]	train's macro_f1: 0.973794	validation's macro_f1: 0.967576
# [100]	train's macro_f1: 0.974101	validation's macro_f1: 0.96751
# Did not meet early stopping. Best iteration is:
# [82]	train's macro_f1: 0.973514	validation's macro_f1: 0.967576
# Training Balanced Accuracy: 0.9553
# Validation Balanced Accuracy: 0.9561
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9982
# Training Macro F1 Score: 0.9735
# Validation Macro F1 Score: 0.9676
# Training Precision (Macro): 0.9975
# Validation Precision (Macro): 0.9921
# ...
# [100]	train's macro_f1: 0.969989	validation's macro_f1: 0.988688
# Did not meet early stopping. Best iteration is:
# [95]	train's macro_f1: 0.969917	validation's macro_f1: 0.988932
# Training Balanced Accuracy: 0.9501
# Validation Balanced Accuracy: 0.9813
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9990
# Training Macro F1 Score: 0.9699
# Validation Macro F1 Score: 0.9889
# Training Precision (Macro): 0.9973
# Validation Precision (Macro): 0.9983
# Training Recall (Macro): 0.9501
# Validation Recall (Macro): 0.9813
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 1.0000
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold23_100.json
# Model for fold 23 saved to ./checkpoints_lgbm_100\model_fold_with_preproc23_100.txt
#
# Fold 24/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.4086	validation's macro_f1: 0.406468
# [10]	train's macro_f1: 0.73881	validation's macro_f1: 0.738376
# [15]	train's macro_f1: 0.759498	validation's macro_f1: 0.752944
# [20]	train's macro_f1: 0.791055	validation's macro_f1: 0.813503
# [25]	train's macro_f1: 0.812197	validation's macro_f1: 0.826228
# [30]	train's macro_f1: 0.821047	validation's macro_f1: 0.827127
# [35]	train's macro_f1: 0.827381	validation's macro_f1: 0.832983
# [40]	train's macro_f1: 0.828853	validation's macro_f1: 0.83324
# [45]	train's macro_f1: 0.829096	validation's macro_f1: 0.834095
# [50]	train's macro_f1: 0.832184	validation's macro_f1: 0.834106
# [55]	train's macro_f1: 0.834359	validation's macro_f1: 0.83637
# [60]	train's macro_f1: 0.906418	validation's macro_f1: 0.951824
# [65]	train's macro_f1: 0.94585	validation's macro_f1: 0.975203
# [70]	train's macro_f1: 0.960665	validation's macro_f1: 0.992431
# [75]	train's macro_f1: 0.96859	validation's macro_f1: 0.992497
# [80]	train's macro_f1: 0.968994	validation's macro_f1: 0.992624
# [85]	train's macro_f1: 0.969101	validation's macro_f1: 0.992624
# [90]	train's macro_f1: 0.969335	validation's macro_f1: 0.992624
# [95]	train's macro_f1: 0.969557	validation's macro_f1: 0.992624
# [100]	train's macro_f1: 0.969818	validation's macro_f1: 0.992624
# Did not meet early stopping. Best iteration is:
# [77]	train's macro_f1: 0.968656	validation's macro_f1: 0.992745
# Training Balanced Accuracy: 0.9484
# Validation Balanced Accuracy: 0.9888
# Training Accuracy: 0.9985
# Validation Accuracy: 0.9983
# Training Macro F1 Score: 0.9687
# Validation Macro F1 Score: 0.9927
# Training Precision (Macro): 0.9966
# Validation Precision (Macro): 0.9969
# Training Recall (Macro): 0.9484
# Validation Recall (Macro): 0.9888
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 1.0000
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold24_100.json
# Model for fold 24 saved to ./checkpoints_lgbm_100\model_fold_with_preproc24_100.txt
#
# Fold 25/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.408373	validation's macro_f1: 0.407972
# [10]	train's macro_f1: 0.739381	validation's macro_f1: 0.741314
# [15]	train's macro_f1: 0.766323	validation's macro_f1: 0.783191
# [20]	train's macro_f1: 0.796696	validation's macro_f1: 0.798149
# [25]	train's macro_f1: 0.816394	validation's macro_f1: 0.804142
# [30]	train's macro_f1: 0.826029	validation's macro_f1: 0.825499
# [35]	train's macro_f1: 0.829764	validation's macro_f1: 0.830509
# [40]	train's macro_f1: 0.830252	validation's macro_f1: 0.830981
# [45]	train's macro_f1: 0.831013	validation's macro_f1: 0.831047
# [50]	train's macro_f1: 0.831647	validation's macro_f1: 0.831057
# [55]	train's macro_f1: 0.840352	validation's macro_f1: 0.835613
# [60]	train's macro_f1: 0.941174	validation's macro_f1: 0.912734
# [65]	train's macro_f1: 0.954485	validation's macro_f1: 0.912668
# [70]	train's macro_f1: 0.967972	validation's macro_f1: 0.914811
# [75]	train's macro_f1: 0.972882	validation's macro_f1: 0.953399
# [80]	train's macro_f1: 0.972944	validation's macro_f1: 0.953399
# [85]	train's macro_f1: 0.973106	validation's macro_f1: 0.953399
# [90]	train's macro_f1: 0.973502	validation's macro_f1: 0.953344
# [95]	train's macro_f1: 0.973748	validation's macro_f1: 0.953465
# [100]	train's macro_f1: 0.973821	validation's macro_f1: 0.953465
# Did not meet early stopping. Best iteration is:
# [91]	train's macro_f1: 0.973605	validation's macro_f1: 0.953465
# Training Balanced Accuracy: 0.9550
# Validation Balanced Accuracy: 0.9353
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9988
# Training Macro F1 Score: 0.9736
# Validation Macro F1 Score: 0.9535
# Training Precision (Macro): 0.9974
# Validation Precision (Macro): 0.9977
# Training Recall (Macro): 0.9550
# Validation Recall (Macro): 0.9353
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9999
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold25_100.json
# Model for fold 25 saved to ./checkpoints_lgbm_100\model_fold_with_preproc25_100.txt
#
# Fold 26/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.411235	validation's macro_f1: 0.409901
# [10]	train's macro_f1: 0.741457	validation's macro_f1: 0.73981
# [15]	train's macro_f1: 0.773603	validation's macro_f1: 0.77917
# [20]	train's macro_f1: 0.803401	validation's macro_f1: 0.80188
# [25]	train's macro_f1: 0.820355	validation's macro_f1: 0.812175
# [30]	train's macro_f1: 0.826448	validation's macro_f1: 0.822149
# [35]	train's macro_f1: 0.82771	validation's macro_f1: 0.825036
# [40]	train's macro_f1: 0.828302	validation's macro_f1: 0.825244
# [45]	train's macro_f1: 0.832232	validation's macro_f1: 0.82797
# [50]	train's macro_f1: 0.832764	validation's macro_f1: 0.830564
# [55]	train's macro_f1: 0.840664	validation's macro_f1: 0.835382
# [60]	train's macro_f1: 0.941227	validation's macro_f1: 0.89885
# [65]	train's macro_f1: 0.960196	validation's macro_f1: 0.89885
# [70]	train's macro_f1: 0.968023	validation's macro_f1: 0.900894
# [75]	train's macro_f1: 0.97279	validation's macro_f1: 0.93948
# [80]	train's macro_f1: 0.973117	validation's macro_f1: 0.96244
# [85]	train's macro_f1: 0.973314	validation's macro_f1: 0.96244
# [90]	train's macro_f1: 0.973515	validation's macro_f1: 0.962691
# [95]	train's macro_f1: 0.973696	validation's macro_f1: 0.962757
# [100]	train's macro_f1: 0.973721	validation's macro_f1: 0.962757
# Did not meet early stopping. Best iteration is:
# [91]	train's macro_f1: 0.973659	validation's macro_f1: 0.962757
# Training Balanced Accuracy: 0.9556
# Validation Balanced Accuracy: 0.9399
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9983
# Training Macro F1 Score: 0.9737
# Validation Macro F1 Score: 0.9628
# Training Precision (Macro): 0.9975
# Validation Precision (Macro): 0.9959
# Training Recall (Macro): 0.9556
# Validation Recall (Macro): 0.9399
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9997
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold26_100.json
# Model for fold 26 saved to ./checkpoints_lgbm_100\model_fold_with_preproc26_100.txt
#
# Fold 27/30
# Before preprocessing: X_train_fold shape: (151170, 83), X_valid_fold shape: (16797, 83)
# After preprocessing: X_train_fold shape: (151170, 94), X_valid_fold shape: (16797, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.415159	validation's macro_f1: 0.413808
# [10]	train's macro_f1: 0.742469	validation's macro_f1: 0.743573
# [15]	train's macro_f1: 0.77997	validation's macro_f1: 0.785018
# [20]	train's macro_f1: 0.801781	validation's macro_f1: 0.810614
# [25]	train's macro_f1: 0.818868	validation's macro_f1: 0.821948
# [30]	train's macro_f1: 0.825228	validation's macro_f1: 0.82692
# [35]	train's macro_f1: 0.827831	validation's macro_f1: 0.827959
# [40]	train's macro_f1: 0.828909	validation's macro_f1: 0.827159
# [45]	train's macro_f1: 0.831466	validation's macro_f1: 0.827346
# [50]	train's macro_f1: 0.832014	validation's macro_f1: 0.830072
# [55]	train's macro_f1: 0.839009	validation's macro_f1: 0.830017
# [60]	train's macro_f1: 0.946877	validation's macro_f1: 0.950549
# [65]	train's macro_f1: 0.961395	validation's macro_f1: 0.952622
# [70]	train's macro_f1: 0.971215	validation's macro_f1: 0.952757
# [75]	train's macro_f1: 0.972096	validation's macro_f1: 0.954904
# [80]	train's macro_f1: 0.972435	validation's macro_f1: 0.954904
# [85]	train's macro_f1: 0.972579	validation's macro_f1: 0.95522
# [90]	train's macro_f1: 0.97267	validation's macro_f1: 0.95522
# [95]	train's macro_f1: 0.972753	validation's macro_f1: 0.95522
# [100]	train's macro_f1: 0.972781	validation's macro_f1: 0.955285
# Did not meet early stopping. Best iteration is:
# [97]	train's macro_f1: 0.972774	validation's macro_f1: 0.955285
# Training Balanced Accuracy: 0.9538
# Validation Balanced Accuracy: 0.9411
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9982
# Training Macro F1 Score: 0.9728
# Validation Macro F1 Score: 0.9553
# Training Precision (Macro): 0.9970
# Validation Precision (Macro): 0.9953
# Training Recall (Macro): 0.9538
# Validation Recall (Macro): 0.9411
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9997
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold27_100.json
# Model for fold 27 saved to ./checkpoints_lgbm_100\model_fold_with_preproc27_100.txt
#
# Fold 28/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 94), X_valid_fold shape: (16796, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.41018	validation's macro_f1: 0.416756
# [10]	train's macro_f1: 0.742793	validation's macro_f1: 0.74465
# [15]	train's macro_f1: 0.776997	validation's macro_f1: 0.770276
# [20]	train's macro_f1: 0.802799	validation's macro_f1: 0.795977
# [25]	train's macro_f1: 0.818771	validation's macro_f1: 0.813173
# [30]	train's macro_f1: 0.825381	validation's macro_f1: 0.816684
# [35]	train's macro_f1: 0.827702	validation's macro_f1: 0.820107
# [40]	train's macro_f1: 0.828573	validation's macro_f1: 0.821154
# [45]	train's macro_f1: 0.829731	validation's macro_f1: 0.824343
# [50]	train's macro_f1: 0.833669	validation's macro_f1: 0.83041
# [55]	train's macro_f1: 0.841236	validation's macro_f1: 0.833112
# [60]	train's macro_f1: 0.951354	validation's macro_f1: 0.949069
# [65]	train's macro_f1: 0.95969	validation's macro_f1: 0.972141
# [70]	train's macro_f1: 0.968798	validation's macro_f1: 0.972273
# [75]	train's macro_f1: 0.969227	validation's macro_f1: 0.972462
# [80]	train's macro_f1: 0.969474	validation's macro_f1: 0.974833
# [85]	train's macro_f1: 0.969676	validation's macro_f1: 0.973767
# [90]	train's macro_f1: 0.971004	validation's macro_f1: 0.973767
# [95]	train's macro_f1: 0.971235	validation's macro_f1: 0.975961
# [100]	train's macro_f1: 0.971435	validation's macro_f1: 0.975961
# Did not meet early stopping. Best iteration is:
# [91]	train's macro_f1: 0.971172	validation's macro_f1: 0.975961
# Training Balanced Accuracy: 0.9517
# Validation Balanced Accuracy: 0.9623
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9982
# Training Macro F1 Score: 0.9712
# Validation Macro F1 Score: 0.9760
# Training Precision (Macro): 0.9969
# Validation Precision (Macro): 0.9952
# Training Recall (Macro): 0.9517
# Validation Recall (Macro): 0.9623
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9994
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold28_100.json
# Model for fold 28 saved to ./checkpoints_lgbm_100\model_fold_with_preproc28_100.txt
#
# Fold 29/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 93), X_valid_fold shape: (16796, 93)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.385123	validation's macro_f1: 0.389761
# [10]	train's macro_f1: 0.743927	validation's macro_f1: 0.73858
# [15]	train's macro_f1: 0.774334	validation's macro_f1: 0.760584
# [20]	train's macro_f1: 0.803787	validation's macro_f1: 0.773633
# [25]	train's macro_f1: 0.819227	validation's macro_f1: 0.789299
# [30]	train's macro_f1: 0.824095	validation's macro_f1: 0.802667
# [35]	train's macro_f1: 0.827693	validation's macro_f1: 0.810666
# [40]	train's macro_f1: 0.830893	validation's macro_f1: 0.817602
# [45]	train's macro_f1: 0.833848	validation's macro_f1: 0.820692
# [50]	train's macro_f1: 0.834995	validation's macro_f1: 0.820833
# [55]	train's macro_f1: 0.835269	validation's macro_f1: 0.820833
# [60]	train's macro_f1: 0.943993	validation's macro_f1: 0.897781
# [65]	train's macro_f1: 0.96865	validation's macro_f1: 0.897916
# [70]	train's macro_f1: 0.9731	validation's macro_f1: 0.936374
# [75]	train's macro_f1: 0.973761	validation's macro_f1: 0.936438
# [80]	train's macro_f1: 0.974329	validation's macro_f1: 0.936703
# [85]	train's macro_f1: 0.974332	validation's macro_f1: 0.936767
# [90]	train's macro_f1: 0.974354	validation's macro_f1: 0.936701
# [95]	train's macro_f1: 0.974402	validation's macro_f1: 0.936703
# [100]	train's macro_f1: 0.974402	validation's macro_f1: 0.936703
# Did not meet early stopping. Best iteration is:
# [85]	train's macro_f1: 0.974332	validation's macro_f1: 0.936767
# Training Balanced Accuracy: 0.9564
# Validation Balanced Accuracy: 0.9124
# Training Accuracy: 0.9986
# Validation Accuracy: 0.9970
# Training Macro F1 Score: 0.9743
# Validation Macro F1 Score: 0.9368
# Training Precision (Macro): 0.9973
# Validation Precision (Macro): 0.9906
# Training Recall (Macro): 0.9564
# Validation Recall (Macro): 0.9124
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9994
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold29_100.json
# Model for fold 29 saved to ./checkpoints_lgbm_100\model_fold_with_preproc29_100.txt
#
# Fold 30/30
# Before preprocessing: X_train_fold shape: (151171, 83), X_valid_fold shape: (16796, 83)
# After preprocessing: X_train_fold shape: (151171, 94), X_valid_fold shape: (16796, 94)
# Training until validation scores don't improve for 50 rounds
# [5]	train's macro_f1: 0.429867	validation's macro_f1: 0.428702
# [10]	train's macro_f1: 0.740102	validation's macro_f1: 0.739791
# [15]	train's macro_f1: 0.755269	validation's macro_f1: 0.748909
# [20]	train's macro_f1: 0.804499	validation's macro_f1: 0.795811
# [25]	train's macro_f1: 0.81788	validation's macro_f1: 0.80916
# [30]	train's macro_f1: 0.823771	validation's macro_f1: 0.820887
# [35]	train's macro_f1: 0.827318	validation's macro_f1: 0.824197
# [40]	train's macro_f1: 0.832717	validation's macro_f1: 0.824292
# [45]	train's macro_f1: 0.833674	validation's macro_f1: 0.827529
# [50]	train's macro_f1: 0.834579	validation's macro_f1: 0.830032
# [55]	train's macro_f1: 0.862841	validation's macro_f1: 0.830032
# [60]	train's macro_f1: 0.947092	validation's macro_f1: 0.88132
# [65]	train's macro_f1: 0.971577	validation's macro_f1: 0.883476
# [70]	train's macro_f1: 0.974597	validation's macro_f1: 0.883242
# [75]	train's macro_f1: 0.974961	validation's macro_f1: 0.921672
# [80]	train's macro_f1: 0.975517	validation's macro_f1: 0.921791
# [85]	train's macro_f1: 0.975775	validation's macro_f1: 0.924049
# [90]	train's macro_f1: 0.975833	validation's macro_f1: 0.923928
# [95]	train's macro_f1: 0.976117	validation's macro_f1: 0.923928
# [100]	train's macro_f1: 0.976551	validation's macro_f1: 0.924048
# Did not meet early stopping. Best iteration is:
# [84]	train's macro_f1: 0.975767	validation's macro_f1: 0.924104
# Training Balanced Accuracy: 0.9590
# Validation Balanced Accuracy: 0.8916
# Training Accuracy: 0.9985
# Validation Accuracy: 0.9974
# Training Macro F1 Score: 0.9758
# Validation Macro F1 Score: 0.9241
# Training Precision (Macro): 0.9971
# Validation Precision (Macro): 0.9957
# Training Recall (Macro): 0.9590
# Validation Recall (Macro): 0.8916
# Training ROC AUC Score: 0.9999
# Validation ROC AUC Score: 0.9986
# Metrics saved to ./checkpoints_lgbm_100\metrics_fold30_100.json
# Model for fold 30 saved to ./checkpoints_lgbm_100\model_fold_with_preproc30_100.txt
# Cross-validation completed successfully.

# %% [markdown]
# -----

# %%
# Function to load all fold metrics
def load_all_fold_metrics(n_folds, metrics_per_fold_path):
    all_train_metrics = []
    all_val_metrics = []
    all_y_true = []
    all_y_pred = []
    all_y_score = []

    for fold in range(n_folds):
        fold = fold + 1
        metrics_file = os.path.join(metrics_per_fold_path, f"metrics_fold{fold}{num_iters}.json")
        if os.path.exists(metrics_file):
            with open(metrics_file, 'r') as f:
                metrics = json.load(f)

                # Extract the metrics
                train_metrics = {
                    'balanced_accuracy': metrics.get('train_balanced_accuracy', None),
                    'accuracy': metrics.get('train_accuracy', None),
                    'macro_f1': metrics.get('train_macro_f1', None),
                    'precision_macro': metrics.get('train_precision_macro', None),
                    'recall_macro': metrics.get('train_recall_macro', None),
                    'auc': metrics.get('train_auc', None)
                }
                val_metrics = {
                    'balanced_accuracy': metrics.get('validation_balanced_accuracy', None),
                    'accuracy': metrics.get('validation_accuracy', None),
                    'macro_f1': metrics.get('validation_macro_f1', None),
                    'precision_macro': metrics.get('validation_precision_macro', None),
                    'recall_macro': metrics.get('validation_recall_macro', None),
                    'auc': metrics.get('validation_auc', None)
                }

                all_train_metrics.append(train_metrics)
                all_val_metrics.append(val_metrics)

                all_y_true.extend(metrics.get('val_y_true', []))
                all_y_pred.extend(metrics.get('val_y_pred', []))
                all_y_score.extend(metrics.get('val_y_score', []))
        else:
            print(f"Metrics file for fold {fold} not found.")

    return all_train_metrics, all_val_metrics, all_y_true, all_y_pred, all_y_score

# %%
# Function to compute mean and std of a specific metric across folds
def mean_and_std(metrics_list, metric_name):
    fold_values = [fold.get(metric_name) for fold in metrics_list if fold.get(metric_name) is not None]
    mean_val = np.mean(fold_values) if fold_values else None
    std_val = np.std(fold_values) if fold_values else None
    return mean_val, std_val

# %%
def compute_and_print_average_metrics(n_folds, metrics_per_fold_path, class_labels):
    """
    Loads all fold metrics, computes average training and validation metrics,
    and prints them in a formatted manner.
    
    Args:
        n_folds (int): Total number of cross-validation folds.
        metrics_per_fold_path (str): Directory path where fold metrics are saved.
        class_labels (list): List of class names.
    """
    # Load all fold metrics
    all_train_metrics, all_val_metrics, all_y_true, all_y_pred, all_y_score = load_all_fold_metrics(n_folds, metrics_per_fold_path)

    # Define metrics to analyze
    metrics_to_analyze = ['balanced_accuracy', 'accuracy', 'macro_f1', 'precision_macro', 'recall_macro', 'auc']

    # Initialize a dictionary to store average metrics
    average_metrics = {}

    print("\n----- Average Cross-Validation Metrics -----\n")
    for metric in metrics_to_analyze:
        train_mean, train_std = mean_and_std(all_train_metrics, metric)
        val_mean, val_std = mean_and_std(all_val_metrics, metric)

        average_metrics[f"train_{metric}"] = (train_mean, train_std)
        average_metrics[f"validation_{metric}"] = (val_mean, val_std)

        # Print the metrics in the desired format
        if train_mean is not None and train_std is not None:
            if metric == 'precision_macro':
                display_metric = 'Precision (Macro)'
            elif metric == 'recall_macro':
                display_metric = 'Recall (Macro)'
            else:
                display_metric = metric.capitalize().replace('_', ' ')
            print(f"Training {display_metric}: {train_mean:.4f} ± {train_std:.4f}")
        if val_mean is not None and val_std is not None:
            if metric == 'precision_macro':
                display_metric = 'Precision (Macro)'
            elif metric == 'recall_macro':
                display_metric = 'Recall (Macro)'
            else:
                display_metric = metric.capitalize().replace('_', ' ')
            print(f"Validation {display_metric}: {val_mean:.4f} ± {val_std:.4f}")
    print("\n--------------------------------------------\n")

    # Generate and save the classification report across all folds
    if all_y_true and all_y_pred:
        final_classification_report = classification_report(all_y_true, all_y_pred, target_names=class_labels, output_dict=True)
        report_df = pd.DataFrame(final_classification_report).transpose()
        report_file = os.path.join(metrics_per_fold_path, f"average_classification_report{num_iters}.csv")
        report_df.to_csv(report_file, index=True)
        print("Average Classification Report:")
        print(report_df)
        print(f"\nClassification report saved to {report_file}\n")

        # Generate and save the confusion matrix across all folds
        cm = confusion_matrix(all_y_true, all_y_pred)
        plt.figure(figsize=FIG_SIZE)
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Average Cross-Validation Confusion Matrix')
        cm_file = os.path.join(metrics_per_fold_path, f'average_confusion_matrix{num_iters}.png')
        plt.savefig(cm_file)
        plt.show()
        plt.close()
        print(f"Average Confusion Matrix saved to {cm_file}\n")
    else:
        print("No predictions found across folds. Skipping classification report and confusion matrix.\n")

    # Clean up to save memory
    del all_train_metrics, all_val_metrics, all_y_true, all_y_pred, all_y_score
    gc.collect()

# %%
def plot_roc_curves(Y_true, Y_score, class_labels, fig_size=(12, 12), save_path=f'./checkpoints_lgbm{num_iters}'):
    """
    Plots ROC curves for each class along with micro and macro averages.

    Args:
        Y_true (array-like): True labels.
        Y_score (array-like): Predicted probabilities.
        class_labels (list): List of class names.
        fig_size (tuple): Size of the plot.
        save_path (str): Directory path to save the ROC curve plot.
    """
    n_classes = CLASSES
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    # Binarize the test labels
    Y_true_bin = label_binarize(Y_true, classes=np.arange(n_classes))

    # Check if the number of classes in predicted probabilities matches
    if Y_score.shape[1] != n_classes:
        print(f"Y_score has shape {Y_score.shape}, expected number of classes {n_classes}")
        return

    # Compute ROC curve and ROC area for each class
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(Y_true_bin[:, i], Y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(Y_true_bin.ravel(), Y_score.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # Compute macro-average ROC curve and ROC area
    # Aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Interpolate all ROC curves at these points and average
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    plt.figure(figsize=fig_size)
    colors = plt.cm.get_cmap('tab10').colors

    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], color=colors[i % len(colors)],
                 lw=2, label=f'ROC curve of class {class_labels[i]} (AUC = {roc_auc[i]:.2f})')

    plt.plot(fpr["micro"], tpr["micro"],
             label=f'micro-average ROC curve (AUC = {roc_auc["micro"]:.2f})',
             color='deeppink', linestyle=':', linewidth=4)

    plt.plot(fpr["macro"], tpr["macro"],
             label=f'macro-average ROC curve (AUC = {roc_auc["macro"]:.2f})',
             color='navy', linestyle=':', linewidth=4)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Test Set ROC Curves')
    plt.legend(loc="lower right", fontsize='small')
    roc_curve_file = os.path.join(save_path, f'test_roc_curves{num_iters}.png')
    plt.savefig(roc_curve_file)
    plt.show()
    plt.close()
    print(f"ROC Curves generated and saved to '{roc_curve_file}'\n")

# %%
# Call the function
total_folds = N_FOLDS * N_REPEATS

# Compute and print average cross-validation metrics
compute_and_print_average_metrics(
    n_folds=total_folds, 
    metrics_per_fold_path=CHECKPOINT_DIR, 
    class_labels=class_labels
)
# Out:
# ----- Average Cross-Validation Metrics -----
#
# Training Balanced accuracy: 0.9529 ± 0.0031
# Validation Balanced accuracy: 0.9472 ± 0.0283
# Training Accuracy: 0.9985 ± 0.0001
# Validation Accuracy: 0.9981 ± 0.0004
# Training Macro f1: 0.9719 ± 0.0020
# Validation Macro f1: 0.9632 ± 0.0216
# Training Precision (Macro): 0.9971 ± 0.0002
# Validation Precision (Macro): 0.9935 ± 0.0137
# Training Recall (Macro): 0.9529 ± 0.0031
# Validation Recall (Macro): 0.9472 ± 0.0283
# Training Auc: 0.9999 ± 0.0000
# Validation Auc: 0.9995 ± 0.0005
#
# --------------------------------------------
#
# Average Classification Report:
#                             precision    recall  f1-score        support
# ARP_poisioning               0.979569  0.987258  0.983398   18600.000000
# Alexa                        0.998782  0.999511  0.999146  208422.000000
# DDOS_Slowloris               0.992765  0.964091  0.978218    1281.000000
# DOS_SYN_Hping                1.000000  1.000000  1.000000  227181.000000
# MQTT_Publish                 1.000000  0.996684  0.998339    9951.000000
# Metasploit_Brute_Force_SSH   1.000000  0.655556  0.791946      90.000000
# NMAP_FIN_SCAN                1.000000  0.863636  0.926829      66.000000
# NMAP_OS_DETECTION            0.999167  1.000000  0.999584    4800.000000
# NMAP_TCP_scan                0.999582  0.995012  0.997292    2406.000000
# NMAP_UDP_SCAN                0.994787  0.982304  0.988506    6216.000000
# NMAP_XMAS_TREE_SCAN          1.000000  0.998134  0.999066    4824.000000
# Thing_Speak                  0.986310  0.984891  0.985600   19458.000000
# Wipro_bulb                   0.998148  0.889439  0.940663     606.000000
# accuracy                     0.998115  0.998115  0.998115       0.998115
# macro avg                    0.996085  0.947424  0.968353  503901.000000
# weighted avg                 0.998119  0.998115  0.998104  503901.000000
#
# Classification report saved to ./checkpoints_lgbm_100\average_classification_report_100.csv
# Average Confusion Matrix saved to ./checkpoints_lgbm_100\average_confusion_matrix_100.png

# %%
# ---------------------------
# 3. Load the Best Model and Evaluate on the Test Set
# ---------------------------

# Path to the best model
best_model_path = os.path.join(CHECKPOINT_DIR, f"best_lgbm_model{num_iters}.txt")
best_model_path = os.path.join(CHECKPOINT_DIR, f"best_lgbm_model{num_iters}.txt")
best_model_with_prep_path = os.path.join(CHECKPOINT_DIR, f"best_lgbm_model_with_preproc_{num_iters}.joblib")

if not os.path.exists(best_model_with_prep_path):
    raise FileNotFoundError(f"No bundle found at {best_model_with_prep_path}. Ensure cross-validation was run successfully.")

print(f"\nLoading bundle (preproc + model) from {best_model_with_prep_path}")
fitted_preproc, booster_str = joblib.load(best_model_with_prep_path)

print(f"\nLoading the best model from {best_model_path}")
# Load the best model
best_model = lgb.Booster(model_str=booster_str)         # re-create model object

# # Check if the best model exists
# if os.path.exists(best_model_path):
#     print(f"\nLoading the best model from {best_model_path}")
#     # Load the best model
#     best_model = lgb.Booster(model_file=best_model_path)
#     print(f"\nBest model loaded from {best_model_path}")
# else:
#     raise FileNotFoundError(f"No best model found at {best_model_path}. Ensure cross-validation was run successfully.")

# # Preprocess the test set
# preprocessor.fit(X_train)  # Ensure the preprocessor is fitted on the entire training set
# X_test_transformed = preprocessor.transform(X_test)

# # Preprocess the test set
X_test_transformed = fitted_preproc.transform(X_test)

# Print the shape before and after preprocessing
print(f"Before preprocessing: X_test shape: {X_test.shape}")
print(f"After preprocessing: X_test_transformed shape: {X_test_transformed.shape}")

# Evaluate on the test set
print("\nEvaluating the best model on the test set...")
Y_test_pred_proba = best_model.predict(X_test_transformed)
Y_test_pred = np.argmax(Y_test_pred_proba.reshape(len(Y_test), -1), axis=1)

# Compute Test Metrics
test_bal_acc = balanced_accuracy_score(Y_test, Y_test_pred)
test_accuracy = accuracy_score(Y_test, Y_test_pred)
test_macro_f1 = f1_score(Y_test, Y_test_pred, average='macro')
test_precision = precision_score(Y_test, Y_test_pred, average='macro', zero_division=0)
test_recall = recall_score(Y_test, Y_test_pred, average='macro', zero_division=0)
Y_test_bin = label_binarize(Y_test, classes=np.arange(CLASSES))
test_auc = roc_auc_score(Y_test_bin, Y_test_pred_proba, average='macro', multi_class='ovo')

# Print Test Metrics
print("\nTest Set Metrics:")
print(f"Test Balanced Accuracy: {test_bal_acc:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Macro F1 Score: {test_macro_f1:.4f}")
print(f"Test Precision (Macro): {test_precision:.4f}")
print(f"Test Recall (Macro): {test_recall:.4f}")
print(f"Test ROC AUC Score: {test_auc:.4f}")

# Save Test Metrics
test_metrics = {
    "test_balanced_accuracy": test_bal_acc,
    "test_accuracy": test_accuracy,
    "test_macro_f1": test_macro_f1,
    "test_precision_macro": test_precision,
    "test_recall_macro": test_recall,
    "test_auc": test_auc,
}
test_metrics_file = os.path.join(CHECKPOINT_DIR, f"test_metrics{num_iters}.json")
with open(test_metrics_file, 'w') as f:
    json.dump(test_metrics, f, indent=4)
print(f"\nTest metrics saved to {test_metrics_file}")

# Classification Report
test_classification_report = classification_report(Y_test, Y_test_pred, target_names=class_labels, output_dict=True)
test_report_df = pd.DataFrame(test_classification_report).transpose()
test_report_file = os.path.join(CHECKPOINT_DIR, f"test_classification_report{num_iters}.csv")
test_report_df.to_csv(test_report_file, index=True)
print(f"Test classification report saved to {test_report_file}")

# Confusion Matrix
cm_test = confusion_matrix(Y_test, Y_test_pred)
plt.figure(figsize=FIG_SIZE)
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Test Set Confusion Matrix')
cm_file = os.path.join(CHECKPOINT_DIR, f'test_confusion_matrix{num_iters}.png')
plt.savefig(cm_file)
plt.show()
plt.close()
print(f"Confusion matrix saved to {cm_file}\n")

# ---------------------------
# 4. Generate ROC Curves
# ---------------------------

def plot_roc_curves(Y_true, Y_score, class_labels, fig_size=(10, 10), save_path="./"):
    """
    Plot ROC curves for multi-class classification.
    """
    n_classes = len(class_labels)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    Y_true_bin = label_binarize(Y_true, classes=np.arange(n_classes))
    if Y_score.shape[1] != n_classes:
        print(f"Y_score has shape {Y_score.shape}, expected number of classes {n_classes}")
        return
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(Y_true_bin[:, i], Y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    plt.figure(figsize=fig_size)
    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], label=f'ROC curve of class {class_labels[i]} (AUC = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")
    plt.savefig(os.path.join(save_path, f"test_set_roc_curve{num_iters}.png"))
    plt.show()
    plt.close()

print("\nGenerating ROC Curves...")
plot_roc_curves(
    Y_true=Y_test,
    Y_score=Y_test_pred_proba,
    class_labels=class_labels,
    fig_size=FIG_SIZE,
    save_path=CHECKPOINT_DIR
)

# Clean up to save memory
gc.collect()
# Out:
# Loading bundle (preproc + model) from ./checkpoints_lgbm_100\best_lgbm_model_with_preproc__100.joblib
#
# Loading the best model from ./checkpoints_lgbm_100\best_lgbm_model_100.txt
# Before preprocessing: X_test shape: (41992, 83)
# After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating the best model on the test set...
#
# Test Set Metrics:
# Test Balanced Accuracy: 0.9686
# Test Accuracy: 0.9981
# Test Macro F1 Score: 0.9808
# Test Precision (Macro): 0.9947
# Test Recall (Macro): 0.9686
# Test ROC AUC Score: 0.9992
#
# Test metrics saved to ./checkpoints_lgbm_100\test_metrics_100.json
# Test classification report saved to ./checkpoints_lgbm_100\test_classification_report_100.csv
# Confusion matrix saved to ./checkpoints_lgbm_100\test_confusion_matrix_100.png
#
#
# Generating ROC Curves...
# 24232

# %%
import os
import joblib
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc

from sklearn.metrics import (
    balanced_accuracy_score,
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    classification_report,
    confusion_matrix,
)
from sklearn.preprocessing import label_binarize

# ---------------------------
# 3. Load All Fold Models (saved as a tuple: (preprocessor, booster)) and Evaluate on the Test Set
# ---------------------------

# List to hold metrics for each fold
all_metrics = []

# Loop through folds 1 to 30 (models saved with .lgbm extension)
for fold in range(1, 31):
    model_path = os.path.join(CHECKPOINT_DIR, f"model_fold_with_preproc{fold}{num_iters}.txt")
    if os.path.exists(model_path):
        # Load the tuple (preprocessor, booster) using joblib.load
        preproc_booster = joblib.load(model_path)
        # Expecting a tuple: (preprocessor, booster)
        preprocessor, booster_str = preproc_booster

        # Load the best model
        booster = lgb.Booster(model_str=booster_str)         # re-create model object
        print(f"\nModel loaded from {model_path}")

        # Use the fold-specific preprocessor to transform the test set
        X_test_transformed = preprocessor.transform(X_test)
        
        # Print the shape before and after preprocessing
        print(f"Fold {fold}: Before preprocessing: X_test shape: {X_test.shape}")
        print(f"Fold {fold}: After preprocessing: X_test_transformed shape: {X_test_transformed.shape}")
        
        # Evaluate on the test set using the booster
        print(f"\nEvaluating fold {fold} on the test set...")
        # LightGBM booster returns probability predictions.
        Y_test_pred_proba = booster.predict(X_test_transformed)
        Y_test_pred = np.argmax(Y_test_pred_proba.reshape(len(Y_test), -1), axis=1)
        
        test_bal_acc = balanced_accuracy_score(Y_test, Y_test_pred)
        test_accuracy = accuracy_score(Y_test, Y_test_pred)
        test_macro_f1 = f1_score(Y_test, Y_test_pred, average='macro')
        test_precision = precision_score(Y_test, Y_test_pred, average='macro', zero_division=0)
        test_recall = recall_score(Y_test, Y_test_pred, average='macro', zero_division=0)
        
        # Convert Y_test to binary for multi-class AUC calculation
        Y_test_bin = label_binarize(Y_test, classes=np.arange(CLASSES))
        test_auc = roc_auc_score(Y_test_bin, Y_test_pred_proba, average='macro', multi_class='ovo')
        
        # Collect metrics for the current fold
        fold_metrics = {
            "fold": fold,
            "balanced_accuracy": test_bal_acc,
            "accuracy": test_accuracy,
            "macro_f1": test_macro_f1,
            "precision_macro": test_precision,
            "recall_macro": test_recall,
            "auc": test_auc,
        }
        all_metrics.append(fold_metrics)
        print(f"Fold {fold} metrics: {fold_metrics}")
    else:
        print(f"Model file not found: {model_path}")

# Convert the list of metrics dictionaries to a DataFrame
metrics_df = pd.DataFrame(all_metrics)

# Calculate the mean and standard deviation for each metric across folds
mean_metrics = metrics_df.mean(numeric_only=True)
std_metrics = metrics_df.std(numeric_only=True)

# Print the aggregated results in "mean ± std" format
print("\nAggregated Metrics Across All Folds:")
for metric in mean_metrics.index:
    mean_val = mean_metrics[metric]
    std_val = std_metrics[metric]
    print(f"{metric}: {mean_val:.4f} ± {std_val:.4f}")

# Save detailed fold metrics and aggregated (mean and std) metrics to a JSON file
aggregated_metrics = {
    "detailed": all_metrics,
    "mean": mean_metrics.to_dict(),
    "std": std_metrics.to_dict(),
}
metrics_file = os.path.join(CHECKPOINT_DIR, f"all_folds_metrics{num_iters}.json")
with open(metrics_file, 'w') as f:
    json.dump(aggregated_metrics, f, indent=4)
print(f"\nAll folds metrics saved to {metrics_file}")

# Clean up to save memory
gc.collect()
# Out:
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc1_100.txt
# Fold 1: Before preprocessing: X_test shape: (41992, 83)
# Fold 1: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 1 on the test set...
# Fold 1 metrics: {'fold': 1, 'balanced_accuracy': 0.9718890075489578, 'accuracy': 0.998237759573252, 'macro_f1': 0.982941102955873, 'precision_macro': 0.995495605336353, 'recall_macro': 0.9718890075489578, 'auc': 0.9993033152692039}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc2_100.txt
# Fold 2: Before preprocessing: X_test shape: (41992, 83)
# Fold 2: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 2 on the test set...
# Fold 2 metrics: {'fold': 2, 'balanced_accuracy': 0.9691499039051016, 'accuracy': 0.9982139455134311, 'macro_f1': 0.9821696567114255, 'precision_macro': 0.9972284262149683, 'recall_macro': 0.9691499039051016, 'auc': 0.9993078260151322}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc3_100.txt
# Fold 3: Before preprocessing: X_test shape: (41992, 83)
# Fold 3: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 3 on the test set...
# Fold 3 metrics: {'fold': 3, 'balanced_accuracy': 0.956754078925152, 'accuracy': 0.998237759573252, 'macro_f1': 0.9753850277286998, 'precision_macro': 0.9971497217316792, 'recall_macro': 0.956754078925152, 'auc': 0.9994032330304367}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc4_100.txt
# Fold 4: Before preprocessing: X_test shape: (41992, 83)
# Fold 4: After preprocessing: X_test_transformed shape: (41992, 93)
#
# Evaluating fold 4 on the test set...
# Fold 4 metrics: {'fold': 4, 'balanced_accuracy': 0.9674434803390957, 'accuracy': 0.9981425033339684, 'macro_f1': 0.9811131297526354, 'precision_macro': 0.9970717963267984, 'recall_macro': 0.9674434803390957, 'auc': 0.9984692388386845}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc5_100.txt
# Fold 5: Before preprocessing: X_test shape: (41992, 83)
# Fold 5: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 5 on the test set...
# Fold 5 metrics: {'fold': 5, 'balanced_accuracy': 0.9628303757697041, 'accuracy': 0.9980472470946847, 'macro_f1': 0.9775713803809628, 'precision_macro': 0.9951760016973237, 'recall_macro': 0.9628303757697041, 'auc': 0.998557637986511}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc6_100.txt
# Fold 6: Before preprocessing: X_test shape: (41992, 83)
# Fold 6: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 6 on the test set...
# Fold 6 metrics: {'fold': 6, 'balanced_accuracy': 0.9627763420582979, 'accuracy': 0.9980234330348637, 'macro_f1': 0.9776604034092499, 'precision_macro': 0.9954053108086777, 'recall_macro': 0.9627763420582979, 'auc': 0.9983850564145764}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc7_100.txt
# Fold 7: Before preprocessing: X_test shape: (41992, 83)
# Fold 7: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 7 on the test set...
# Fold 7 metrics: {'fold': 7, 'balanced_accuracy': 0.9669182139074837, 'accuracy': 0.9980234330348637, 'macro_f1': 0.979482160282189, 'precision_macro': 0.994017824093516, 'recall_macro': 0.9669182139074837, 'auc': 0.9985568699451746}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc8_100.txt
# Fold 8: Before preprocessing: X_test shape: (41992, 83)
# Fold 8: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 8 on the test set...
# Fold 8 metrics: {'fold': 8, 'balanced_accuracy': 0.9693421162795315, 'accuracy': 0.9982853876928939, 'macro_f1': 0.9822662175817386, 'precision_macro': 0.9972270226066692, 'recall_macro': 0.9693421162795315, 'auc': 0.9994109756917287}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc9_100.txt
# Fold 9: Before preprocessing: X_test shape: (41992, 83)
# Fold 9: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 9 on the test set...
# Fold 9 metrics: {'fold': 9, 'balanced_accuracy': 0.9659392074068058, 'accuracy': 0.9980710611545056, 'macro_f1': 0.9802607036573696, 'precision_macro': 0.9971562437968616, 'recall_macro': 0.9659392074068058, 'auc': 0.9991544091012124}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc10_100.txt
# Fold 10: Before preprocessing: X_test shape: (41992, 83)
# Fold 10: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 10 on the test set...
# Fold 10 metrics: {'fold': 10, 'balanced_accuracy': 0.964142363189315, 'accuracy': 0.997975804915222, 'macro_f1': 0.9791451488861005, 'precision_macro': 0.9970497158699706, 'recall_macro': 0.964142363189315, 'auc': 0.9985184474133407}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc11_100.txt
# Fold 11: Before preprocessing: X_test shape: (41992, 83)
# Fold 11: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 11 on the test set...
# Fold 11 metrics: {'fold': 11, 'balanced_accuracy': 0.9686224576055243, 'accuracy': 0.9981186892741475, 'macro_f1': 0.9807923316087959, 'precision_macro': 0.9947446853075098, 'recall_macro': 0.9686224576055243, 'auc': 0.9992054954009982}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc12_100.txt
# Fold 12: Before preprocessing: X_test shape: (41992, 83)
# Fold 12: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 12 on the test set...
# Fold 12 metrics: {'fold': 12, 'balanced_accuracy': 0.9677894114181598, 'accuracy': 0.9983806439321775, 'macro_f1': 0.9811056697512908, 'precision_macro': 0.996679234119305, 'recall_macro': 0.9677894114181598, 'auc': 0.9991756093129615}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc13_100.txt
# Fold 13: Before preprocessing: X_test shape: (41992, 83)
# Fold 13: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 13 on the test set...
# Fold 13 metrics: {'fold': 13, 'balanced_accuracy': 0.970335513143251, 'accuracy': 0.9982139455134311, 'macro_f1': 0.9821913633705209, 'precision_macro': 0.9956892995544041, 'recall_macro': 0.970335513143251, 'auc': 0.9992543916574854}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc14_100.txt
# Fold 14: Before preprocessing: X_test shape: (41992, 83)
# Fold 14: After preprocessing: X_test_transformed shape: (41992, 93)
#
# Evaluating fold 14 on the test set...
# Fold 14 metrics: {'fold': 14, 'balanced_accuracy': 0.9694419216787961, 'accuracy': 0.9983806439321775, 'macro_f1': 0.9817062295669936, 'precision_macro': 0.9957902735210807, 'recall_macro': 0.9694419216787961, 'auc': 0.9982139729783597}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc15_100.txt
# Fold 15: Before preprocessing: X_test shape: (41992, 83)
# Fold 15: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 15 on the test set...
# Fold 15 metrics: {'fold': 15, 'balanced_accuracy': 0.9689198411287142, 'accuracy': 0.9982139455134311, 'macro_f1': 0.9820252999238235, 'precision_macro': 0.9971691492381487, 'recall_macro': 0.9689198411287142, 'auc': 0.9995808826166924}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc16_100.txt
# Fold 16: Before preprocessing: X_test shape: (41992, 83)
# Fold 16: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 16 on the test set...
# Fold 16 metrics: {'fold': 16, 'balanced_accuracy': 0.970514438482284, 'accuracy': 0.9982139455134311, 'macro_f1': 0.9820978345496195, 'precision_macro': 0.9953239588691101, 'recall_macro': 0.970514438482284, 'auc': 0.9994499859953236}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc17_100.txt
# Fold 17: Before preprocessing: X_test shape: (41992, 83)
# Fold 17: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 17 on the test set...
# Fold 17 metrics: {'fold': 17, 'balanced_accuracy': 0.967499740102379, 'accuracy': 0.9981901314536102, 'macro_f1': 0.9805215006942235, 'precision_macro': 0.9955666021793098, 'recall_macro': 0.967499740102379, 'auc': 0.9992266295181141}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc18_100.txt
# Fold 18: Before preprocessing: X_test shape: (41992, 83)
# Fold 18: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 18 on the test set...
# Fold 18 metrics: {'fold': 18, 'balanced_accuracy': 0.9675986124593159, 'accuracy': 0.9981901314536102, 'macro_f1': 0.9811880572413634, 'precision_macro': 0.9970624283491686, 'recall_macro': 0.9675986124593159, 'auc': 0.9985032843610324}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc19_100.txt
# Fold 19: Before preprocessing: X_test shape: (41992, 83)
# Fold 19: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 19 on the test set...
# Fold 19 metrics: {'fold': 19, 'balanced_accuracy': 0.9704237308348141, 'accuracy': 0.998237759573252, 'macro_f1': 0.9822162126026738, 'precision_macro': 0.9956505500460309, 'recall_macro': 0.9704237308348141, 'auc': 0.9993739663311438}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc20_100.txt
# Fold 20: Before preprocessing: X_test shape: (41992, 83)
# Fold 20: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 20 on the test set...
# Fold 20 metrics: {'fold': 20, 'balanced_accuracy': 0.9627652810747788, 'accuracy': 0.997975804915222, 'macro_f1': 0.9783390270447632, 'precision_macro': 0.9971799052223075, 'recall_macro': 0.9627652810747788, 'auc': 0.9985687413758298}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc21_100.txt
# Fold 21: Before preprocessing: X_test shape: (41992, 83)
# Fold 21: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 21 on the test set...
# Fold 21 metrics: {'fold': 21, 'balanced_accuracy': 0.9689083738270494, 'accuracy': 0.9980948752143265, 'macro_f1': 0.9819929249946191, 'precision_macro': 0.9971162275360038, 'recall_macro': 0.9689083738270494, 'auc': 0.9992753100274844}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc22_100.txt
# Fold 22: Before preprocessing: X_test shape: (41992, 83)
# Fold 22: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 22 on the test set...
# Fold 22 metrics: {'fold': 22, 'balanced_accuracy': 0.9674119518209174, 'accuracy': 0.998261573633073, 'macro_f1': 0.9802156305871909, 'precision_macro': 0.9950120070815178, 'recall_macro': 0.9674119518209174, 'auc': 0.9984182625505139}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc23_100.txt
# Fold 23: Before preprocessing: X_test shape: (41992, 83)
# Fold 23: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 23 on the test set...
# Fold 23 metrics: {'fold': 23, 'balanced_accuracy': 0.9661771914690943, 'accuracy': 0.9982139455134311, 'macro_f1': 0.9800586429858171, 'precision_macro': 0.9964845650846275, 'recall_macro': 0.9661771914690943, 'auc': 0.9993845091042383}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc24_100.txt
# Fold 24: Before preprocessing: X_test shape: (41992, 83)
# Fold 24: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 24 on the test set...
# Fold 24 metrics: {'fold': 24, 'balanced_accuracy': 0.9690014037566015, 'accuracy': 0.9981901314536102, 'macro_f1': 0.981375098571027, 'precision_macro': 0.9955640090630467, 'recall_macro': 0.9690014037566015, 'auc': 0.9986710331461327}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc25_100.txt
# Fold 25: Before preprocessing: X_test shape: (41992, 83)
# Fold 25: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 25 on the test set...
# Fold 25 metrics: {'fold': 25, 'balanced_accuracy': 0.9689675760482973, 'accuracy': 0.9982139455134311, 'macro_f1': 0.9813073837676254, 'precision_macro': 0.9954611491953784, 'recall_macro': 0.9689675760482973, 'auc': 0.9994038375284675}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc26_100.txt
# Fold 26: Before preprocessing: X_test shape: (41992, 83)
# Fold 26: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 26 on the test set...
# Fold 26 metrics: {'fold': 26, 'balanced_accuracy': 0.970479990598098, 'accuracy': 0.9982853876928939, 'macro_f1': 0.9829618640453119, 'precision_macro': 0.9972694488925776, 'recall_macro': 0.970479990598098, 'auc': 0.9987249435102291}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc27_100.txt
# Fold 27: Before preprocessing: X_test shape: (41992, 83)
# Fold 27: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 27 on the test set...
# Fold 27 metrics: {'fold': 27, 'balanced_accuracy': 0.9706537474272892, 'accuracy': 0.9981901314536102, 'macro_f1': 0.9820752932548765, 'precision_macro': 0.9951382059810057, 'recall_macro': 0.9706537474272892, 'auc': 0.9994461196050316}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc28_100.txt
# Fold 28: Before preprocessing: X_test shape: (41992, 83)
# Fold 28: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 28 on the test set...
# Fold 28 metrics: {'fold': 28, 'balanced_accuracy': 0.9689238638223675, 'accuracy': 0.9981663173937892, 'macro_f1': 0.9812820284949707, 'precision_macro': 0.9954524731864692, 'recall_macro': 0.9689238638223675, 'auc': 0.9993336137717734}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc29_100.txt
# Fold 29: Before preprocessing: X_test shape: (41992, 83)
# Fold 29: After preprocessing: X_test_transformed shape: (41992, 93)
#
# Evaluating fold 29 on the test set...
# Fold 29 metrics: {'fold': 29, 'balanced_accuracy': 0.9641986460445546, 'accuracy': 0.9980472470946847, 'macro_f1': 0.9784821442641827, 'precision_macro': 0.9953077081519037, 'recall_macro': 0.9641986460445546, 'auc': 0.9978141981505769}
#
# Model loaded from ./checkpoints_lgbm_100\model_fold_with_preproc30_100.txt
# Fold 30: Before preprocessing: X_test shape: (41992, 83)
# Fold 30: After preprocessing: X_test_transformed shape: (41992, 94)
#
# Evaluating fold 30 on the test set...
# Fold 30 metrics: {'fold': 30, 'balanced_accuracy': 0.9671997011172098, 'accuracy': 0.997975804915222, 'macro_f1': 0.9801240748429275, 'precision_macro': 0.9950728681034409, 'recall_macro': 0.9671997011172098, 'auc': 0.9985638325878222}
#
# Aggregated Metrics Across All Folds:
# fold: 15.5000 ± 8.8034
# balanced_accuracy: 0.9674 ± 0.0032
# accuracy: 0.9982 ± 0.0001
# macro_f1: 0.9807 ± 0.0018
# precision_macro: 0.9961 ± 0.0010
# recall_macro: 0.9674 ± 0.0032
# auc: 0.9990 ± 0.0005
#
# All folds metrics saved to ./checkpoints_lgbm_100\all_folds_metrics_100.json
# 353
